# %%
# Imports
import tensorflow as tf
import numpy as np
import glob
import csv
import os
import random

# %%
# Access data
def get_data(data_dir, labels_path):
    data_filenames = glob.glob(os.path.join(data_dir, '*npy'))
    random.shuffle(data_filenames)

    num_examples = len(data_filenames)
    
    labels_dict = {}
    get_labels_dict(labels_path, labels_dict)
    
    X = np.zeros([num_examples, 151, 100])
    Y = np.zeros(num_examples)
    for i, df in enumerate(data_filenames):
        X[i, :, :] = np.load(df)
        
        label_key = df.split('/')[-1].split('.')[0].split('_')[0]
        Y[i] = labels_dict[label_key]
        
    # Convert -1 labels to 0
    Y[np.where(Y == -1)] = 0
        
    return X.astype(np.float32), Y.astype(np.float32)


def get_labels_dict(reference_path, reference):
    with open(reference_path) as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            reference[row[0]] = row[1]

# %%
# Helper functions for defining variables in the network graph
def _variable_on_cpu(name, shape, initializer):
    """
    Helper to create a Variable stored on CPU memory.
    """

    with tf.device('/cpu:0'):
        var = tf.get_variable(
            name=name, 
            shape=shape, 
            dtype=tf.float32, 
            initializer=initializer)

    return var

def _variable_with_weight_decay(name, shape, stddev, wd):
    """
    Helper to create an initialized Variable with weight decay.
    """

    var = _variable_on_cpu(
        name=name,
        shape=shape,
        initializer=tf.truncated_normal_initializer(
            stddev=stddev,
            dtype=tf.float32))

    if wd is not None:
        weight_decay = tf.multiply(tf.nn.l2_loss(var), wd, 
                                   name='weight_loss')
        tf.add_to_collection('losses', weight_decay)

    return var


def loss(unscale_logits, labels):
    """
    Add L2Loss to all the trainable variables.
    """

    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(
        labels=labels,
        logits=unscale_logits,
        name='cross_entropy')

    cross_entropy_mean = tf.reduce_mean(cross_entropy, name='cross_entropy')

    tf.add_to_collection('losses', cross_entropy_mean)

    total_loss = tf.add_n(tf.get_collection('losses'), name='total_loss')

    return total_loss

# %%
# Function for defining CNN network 
# (window size = 300)
def cnn(features):

    # Input Layer.
    input_layer = tf.reshape(features["x"], [-1, 151, 100, 1])

    # Convolutional layer #1.
    with tf.variable_scope(name_or_scope='conv1') as scope:
        kernel = _variable_with_weight_decay(
            name='weights',
            shape=[5, 5, 1, 64],
            stddev=5e-2,
            wd=0.0)

        conv = tf.nn.conv2d(
            input=input_layer,
            filter=kernel,
            strides=[1, 1, 1, 1],
            padding='SAME')

        biases = _variable_on_cpu(
            name='biases',
            shape=[64],
            initializer=tf.constant_initializer(0.0))

        pre_activation = tf.nn.bias_add(conv, biases)

        conv1 = tf.nn.tanh(
            x=pre_activation, 
            name=scope.name)
        
        
    # Max pooling layer #1.
    pool1 = tf.nn.max_pool(
        value=conv1,
        ksize=[1, 3, 3, 1], 
        strides=[1, 2, 2, 1],
        padding='SAME', 
        name='pool1')

    
    # Local response normalization layer #1.
    norm1 = tf.nn.lrn(
        input=pool1, 
        depth_radius=4, 
        bias=1.0, 
        alpha=0.001 / 9.0, 
        beta=0.75,
        name='norm1')
    
    # Convolutional layer #2.
    with tf.variable_scope(name_or_scope='conv2') as scope:
        kernel = _variable_with_weight_decay(
            name='weights',
            shape=[5, 5, 64, 64],
            stddev=5e-2,
            wd=0.0)

        conv = tf.nn.conv2d(
            input=norm1,
            filter=kernel,
            strides=[1, 1, 1, 1],
            padding='SAME')

        biases = _variable_on_cpu(
            name='biases',
            shape=[64],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.nn.bias_add(conv, biases)

        conv2 = tf.nn.tanh(
            x=pre_activation, 
            name=scope.name)

    # Local response normalization layer #2.
    norm2 = tf.nn.lrn(
        input=conv2, 
        depth_radius=4, 
        bias=1.0, 
        alpha=0.001 / 9.0, 
        beta=0.75,
        name='norm2')

    # Max pooling layer #2.
    pool2 = tf.nn.max_pool(
        value=norm2,
        ksize=[1, 3, 3, 1], 
        strides=[1, 2, 2, 1],
        padding='SAME', 
        name='pool2')

    # Fully connected layer #1.
    with tf.variable_scope(name_or_scope='fc1') as scope:
        flat = tf.reshape(pool2, [-1, 60800])

        weights = _variable_with_weight_decay(
            name='weights',
            shape=[60800, 384],
            stddev=0.04,
            wd=0.004)

        biases = _variable_on_cpu(
            name='biases',
            shape=[384],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.add(tf.matmul(flat, weights), biases)

        fc1 = tf.nn.relu(
            features=pre_activation,
            name=scope.name)

        
    # Fully connected layer #2.
    with tf.variable_scope(name_or_scope='fc2') as scope:
        weights = _variable_with_weight_decay(
            name='weights',
            shape=[384, 192],
            stddev=0.04,
            wd=0.004)

        biases = _variable_on_cpu(
            name='biases',
            shape=[192],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.add(tf.matmul(fc1, weights), biases)

        fc2 = tf.nn.relu(
            features=pre_activation,
            name=scope.name)

        
    # Unscaled logits layer #1.
    with tf.variable_scope(name_or_scope='logits1') as scope:
        weights = _variable_with_weight_decay(
            name='weights',
            shape=[192, 2],
            stddev=1.0 / 192.0,
            wd=0.0)

        biases = _variable_on_cpu(
            name='biases',
            shape=[2],
            initializer=tf.constant_initializer(0.0))

        unscale_logits = tf.add(tf.matmul(fc2, weights), biases)
        
    return unscale_logits

# %%
# Function for defining CNN network
# (window size = 500)
def cnn2(features):

    # Input Layer.
    input_layer = tf.reshape(features["x"], [-1, 251, 100, 1])

    # Convolutional layer #1.
    with tf.variable_scope(name_or_scope='conv1') as scope:
        kernel = _variable_with_weight_decay(
            name='weights',
            shape=[5, 5, 1, 64],
            stddev=5e-2,
            wd=0.0)

        conv = tf.nn.conv2d(
            input=input_layer,
            filter=kernel,
            strides=[1, 1, 1, 1],
            padding='SAME')

        biases = _variable_on_cpu(
            name='biases',
            shape=[64],
            initializer=tf.constant_initializer(0.0))

        pre_activation = tf.nn.bias_add(conv, biases)

        conv1 = tf.nn.tanh(
            x=pre_activation, 
            name=scope.name)
        
        
    # Max pooling layer #1.
    pool1 = tf.nn.max_pool(
        value=conv1,
        ksize=[1, 3, 3, 1], 
        strides=[1, 2, 2, 1],
        padding='SAME', 
        name='pool1')

    
    # Local response normalization layer #1.
    norm1 = tf.nn.lrn(
        input=pool1, 
        depth_radius=4, 
        bias=1.0, 
        alpha=0.001 / 9.0, 
        beta=0.75,
        name='norm1')
    
    # Convolutional layer #2.
    with tf.variable_scope(name_or_scope='conv2') as scope:
        kernel = _variable_with_weight_decay(
            name='weights',
            shape=[5, 5, 64, 64],
            stddev=5e-2,
            wd=0.0)

        conv = tf.nn.conv2d(
            input=norm1,
            filter=kernel,
            strides=[1, 1, 1, 1],
            padding='SAME')

        biases = _variable_on_cpu(
            name='biases',
            shape=[64],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.nn.bias_add(conv, biases)

        conv2 = tf.nn.tanh(
            x=pre_activation, 
            name=scope.name)

    # Local response normalization layer #2.
    norm2 = tf.nn.lrn(
        input=conv2, 
        depth_radius=4, 
        bias=1.0, 
        alpha=0.001 / 9.0, 
        beta=0.75,
        name='norm2')

    # Max pooling layer #2.
    pool2 = tf.nn.max_pool(
        value=norm2,
        ksize=[1, 3, 3, 1], 
        strides=[1, 2, 2, 1],
        padding='SAME', 
        name='pool2')

    # Fully connected layer #1.
    with tf.variable_scope(name_or_scope='fc1') as scope:
        flat = tf.reshape(pool2, [-1, 100800])

        weights = _variable_with_weight_decay(
            name='weights',
            shape=[100800, 384],
            stddev=0.04,
            wd=0.004)

        biases = _variable_on_cpu(
            name='biases',
            shape=[384],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.add(tf.matmul(flat, weights), biases)

        fc1 = tf.nn.relu(
            features=pre_activation,
            name=scope.name)

        
    # Fully connected layer #2.
    with tf.variable_scope(name_or_scope='fc2') as scope:
        weights = _variable_with_weight_decay(
            name='weights',
            shape=[384, 192],
            stddev=0.04,
            wd=0.004)

        biases = _variable_on_cpu(
            name='biases',
            shape=[192],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.add(tf.matmul(fc1, weights), biases)

        fc2 = tf.nn.relu(
            features=pre_activation,
            name=scope.name)

        
    # Unscaled logits layer #1.
    with tf.variable_scope(name_or_scope='logits1') as scope:
        weights = _variable_with_weight_decay(
            name='weights',
            shape=[192, 2],
            stddev=1.0 / 192.0,
            wd=0.0)

        biases = _variable_on_cpu(
            name='biases',
            shape=[2],
            initializer=tf.constant_initializer(0.0))

        unscale_logits = tf.add(tf.matmul(fc2, weights), biases)
        
    return unscale_logits

# %%
# Function for building CNN network
def cnn_model_fn(features, labels, mode):
    """
    Build model.
    """
    unscale_logits = cnn(features)
        
    # Generate predictions for PREDICT and EVAL modes.
    predictions = {
        'classes': tf.argmax(input=unscale_logits, axis=1),
        'probabilities': tf.nn.softmax(unscale_logits, name='softmax_tensor')
    }
    
    ####################
    # PREDICT
    ####################
    if mode == tf.estimator.ModeKeys.PREDICT: 
        return tf.estimator.EstimatorSpec(mode=mode, 
                                          predictions=predictions['probabilities'])
    
    else:
        # Calculate loss for both TRAIN and EVAL modes.
        labels = tf.cast(labels, tf.int64)
        total_loss = loss(unscale_logits, labels)

        # Add summary operation for total loss visualizaiton.
        tf.summary.scalar(
            name='total_loss',
            tensor=total_loss)
    

        ####################
        # TRAIN
        ####################
        if mode == tf.estimator.ModeKeys.TRAIN:

            # Compute gradients using Gradient Descent Optimizer.
            optimizer = tf.train.AdamOptimizer()

            grads_vars = optimizer.compute_gradients(loss=total_loss)

            # Add summary operations for gradient visualizations.
            for grad, var in grads_vars:
                if grad is not None:
                    tf.summary.histogram(
                        name=var.op.name + '/gradients', 
                        values=grad)

            train_op = optimizer.minimize(
                loss=total_loss,
                global_step=tf.train.get_global_step())

            # Add evaluation metrics for TRAIN mode.
            accuracy_train = tf.metrics.accuracy(
                labels=labels, 
                predictions=predictions["classes"])

            # Add summary operation for training accuracy visualizaiton.
            tf.summary.scalar(
                name='accuracy_train',
                tensor=accuracy_train[0])

            train_summary_hook = tf.train.SummarySaverHook(
                save_steps=10,
                output_dir='models/cnn',
                summary_op=tf.summary.merge_all())

            return tf.estimator.EstimatorSpec(
                mode=mode,
                loss=total_loss, 
                train_op=train_op,
                training_hooks=[train_summary_hook])

        
        ####################
        # EVALUATE
        ####################
        else:
            accuracy_valid = tf.metrics.accuracy(
                labels=labels, 
                predictions=predictions["classes"])

            # Add summary operation for validation accuracy visualizaiton.
            tf.summary.scalar(
                name='accuracy_validation',
                tensor=accuracy_valid[0])

            eval_metric_ops = {"accuracy": accuracy_valid}

            eval_summary_hook = tf.train.SummarySaverHook(
                save_steps=1,
                output_dir='models/cnn',
                summary_op=tf.summary.merge_all())

            return tf.estimator.EstimatorSpec(
                mode=mode, 
                loss=total_loss, 
                eval_metric_ops=eval_metric_ops,
                training_hooks=[eval_summary_hook])

# %%
# Main function for building, training and evaluating model.
def main(train_data, train_labels, eval_data, eval_labels, test_data):
    
    estimator_dir = 'models/cnn'
    
    # Delete directory containing events logs and checkpoints if it exists.
    if tf.gfile.Exists(estimator_dir):
        tf.gfile.DeleteRecursively(estimator_dir)
        
    # Create directory containing events logs and checkpoints.
    tf.gfile.MakeDirs(estimator_dir)
    
    # Create the Estimator.
    classifier = tf.estimator.Estimator(
        model_fn=cnn_model_fn, 
        model_dir=estimator_dir)

    for _ in range(100):
        
        # Train the model.
        train_input_fn = tf.estimator.inputs.numpy_input_fn(
            x={"x": train_data},
            y=train_labels,
            batch_size=96,
            num_epochs=None,
            shuffle=True)

        classifier.train(
            input_fn=train_input_fn,
            steps=25)

        # Evaluate the model and print results.
        eval_input_fn = tf.estimator.inputs.numpy_input_fn(
            x={"x": eval_data},
            y=eval_labels,
            num_epochs=1,
            shuffle=False)
    
        eval_results = classifier.evaluate(input_fn=eval_input_fn)
        print(eval_results)
        
    # Generate predictions on test set.
    predict_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": test_data},
      num_epochs=1,
      shuffle=False)

    predictions = np.array(list(classifier.predict(input_fn=predict_input_fn))).T
    
    return predictions

# %%
# Load training and validation data
# NOTE: moved all data files to flashdrive
train_dir = 'data/spectrogram/training/'
valid_dir = 'data/spectrogram/validation/'

X_train, Y_train = get_data(os.path.join(train_dir, 'sub_ws300'), 
                            os.path.join(train_dir, 'REFERENCE.csv'))
                            
X_valid, Y_valid = get_data(os.path.join(valid_dir, 'sub_ws300'), 
                            os.path.join(valid_dir, 'REFERENCE.csv'))

# %%
# Run network
# RERUN FROM LAST SAVE POINT
pred = main(X_train, Y_train, X_valid, Y_valid, X_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_model_dir': 'models/cnn', '_tf_random_seed': 1, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1, loss = 58.7046
# INFO:tensorflow:Saving checkpoints for 25 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 23.1668.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:03:30
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-25
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:04:08
# INFO:tensorflow:Saving dict for global step 25: accuracy = 0.517668, global_step = 25, loss = 22.4392
# {'global_step': 25, 'loss': 22.439217, 'accuracy': 0.51766783}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-25
# INFO:tensorflow:Saving checkpoints for 26 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 26, loss = 22.0529
# INFO:tensorflow:Saving checkpoints for 50 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 6.87706.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:10:19
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-50
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:11:06
# INFO:tensorflow:Saving dict for global step 50: accuracy = 0.538869, global_step = 50, loss = 7.06697
# {'global_step': 50, 'loss': 7.0669703, 'accuracy': 0.53886926}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-50
# INFO:tensorflow:Saving checkpoints for 51 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 51, loss = 6.62158
# INFO:tensorflow:Saving checkpoints for 75 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.1972.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:19:01
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-75
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:19:48
# INFO:tensorflow:Saving dict for global step 75: accuracy = 0.610424, global_step = 75, loss = 2.57108
# {'global_step': 75, 'loss': 2.5710793, 'accuracy': 0.61042404}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-75
# INFO:tensorflow:Saving checkpoints for 76 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 76, loss = 2.09531
# INFO:tensorflow:Saving checkpoints for 100 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.802813.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:27:28
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-100
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:28:14
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.710247, global_step = 100, loss = 1.03343
# {'global_step': 100, 'loss': 1.0334258, 'accuracy': 0.71024734}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-100
# INFO:tensorflow:Saving checkpoints for 101 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 101, loss = 0.830687
# INFO:tensorflow:Saving checkpoints for 125 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.465004.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:34:12
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-125
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:35:02
# INFO:tensorflow:Saving dict for global step 125: accuracy = 0.672261, global_step = 125, loss = 0.801633
# {'global_step': 125, 'loss': 0.80163318, 'accuracy': 0.67226148}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-125
# INFO:tensorflow:Saving checkpoints for 126 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 126, loss = 0.40003
# INFO:tensorflow:Saving checkpoints for 150 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.423289.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:41:16
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-150
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:42:02
# INFO:tensorflow:Saving dict for global step 150: accuracy = 0.778269, global_step = 150, loss = 0.590938
# {'global_step': 150, 'loss': 0.59093833, 'accuracy': 0.77826858}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-150
# INFO:tensorflow:Saving checkpoints for 151 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 151, loss = 0.347636
# INFO:tensorflow:Saving checkpoints for 175 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.385968.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:47:36
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-175
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:48:16
# INFO:tensorflow:Saving dict for global step 175: accuracy = 0.777385, global_step = 175, loss = 0.57641
# {'global_step': 175, 'loss': 0.5764097, 'accuracy': 0.77738518}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-175
# INFO:tensorflow:Saving checkpoints for 176 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 176, loss = 0.365668
# INFO:tensorflow:Saving checkpoints for 200 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.437076.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:53:28
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-200
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:54:09
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.704064, global_step = 200, loss = 0.689857
# {'global_step': 200, 'loss': 0.68985748, 'accuracy': 0.70406359}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-200
# INFO:tensorflow:Saving checkpoints for 201 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 201, loss = 0.299936
# INFO:tensorflow:Saving checkpoints for 225 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.318233.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:59:36
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-225
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:00:18
# INFO:tensorflow:Saving dict for global step 225: accuracy = 0.780919, global_step = 225, loss = 0.577168
# {'global_step': 225, 'loss': 0.57716787, 'accuracy': 0.78091872}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-225
# INFO:tensorflow:Saving checkpoints for 226 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 226, loss = 0.368665
# INFO:tensorflow:Saving checkpoints for 250 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.374057.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:05:30
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-250
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:06:12
# INFO:tensorflow:Saving dict for global step 250: accuracy = 0.690813, global_step = 250, loss = 0.690539
# {'global_step': 250, 'loss': 0.69053936, 'accuracy': 0.69081271}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-250
# INFO:tensorflow:Saving checkpoints for 251 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 251, loss = 0.389367
# INFO:tensorflow:Saving checkpoints for 275 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.356502.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:11:31
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-275
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:12:12
# INFO:tensorflow:Saving dict for global step 275: accuracy = 0.782686, global_step = 275, loss = 0.584296
# {'global_step': 275, 'loss': 0.58429646, 'accuracy': 0.78268552}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-275
# INFO:tensorflow:Saving checkpoints for 276 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 276, loss = 0.335445
# INFO:tensorflow:Saving checkpoints for 300 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.20474.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:17:28
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-300
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:18:09
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.710247, global_step = 300, loss = 0.740953
# {'global_step': 300, 'loss': 0.74095279, 'accuracy': 0.71024734}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-300
# INFO:tensorflow:Saving checkpoints for 301 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 301, loss = 0.359997
# INFO:tensorflow:Saving checkpoints for 325 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.339796.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:23:18
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-325
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:23:59
# INFO:tensorflow:Saving dict for global step 325: accuracy = 0.737633, global_step = 325, loss = 0.610209
# {'global_step': 325, 'loss': 0.61020923, 'accuracy': 0.73763251}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-325
# INFO:tensorflow:Saving checkpoints for 326 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 326, loss = 0.273327
# INFO:tensorflow:Saving checkpoints for 350 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.354829.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:29:21
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-350
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:30:02
# INFO:tensorflow:Saving dict for global step 350: accuracy = 0.727915, global_step = 350, loss = 0.69192
# {'global_step': 350, 'loss': 0.69191992, 'accuracy': 0.72791517}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-350
# INFO:tensorflow:Saving checkpoints for 351 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 351, loss = 0.214358
# INFO:tensorflow:Saving checkpoints for 375 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.402473.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:35:11
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-375
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:35:52
# INFO:tensorflow:Saving dict for global step 375: accuracy = 0.719081, global_step = 375, loss = 0.674167
# {'global_step': 375, 'loss': 0.67416656, 'accuracy': 0.71908128}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-375
# INFO:tensorflow:Saving checkpoints for 376 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 376, loss = 0.402677
# INFO:tensorflow:Saving checkpoints for 400 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.346958.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:41:11
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-400
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:41:51
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.733216, global_step = 400, loss = 0.688115
# {'global_step': 400, 'loss': 0.68811512, 'accuracy': 0.73321557}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-400
# INFO:tensorflow:Saving checkpoints for 401 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 401, loss = 0.259806
# INFO:tensorflow:Saving checkpoints for 425 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.325824.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:47:06
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-425
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:47:47
# INFO:tensorflow:Saving dict for global step 425: accuracy = 0.745583, global_step = 425, loss = 0.559055
# {'global_step': 425, 'loss': 0.55905503, 'accuracy': 0.74558306}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-425
# INFO:tensorflow:Saving checkpoints for 426 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 426, loss = 0.280334
# INFO:tensorflow:Saving checkpoints for 450 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.207837.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:52:57
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-450
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:53:38
# INFO:tensorflow:Saving dict for global step 450: accuracy = 0.779152, global_step = 450, loss = 0.554078
# {'global_step': 450, 'loss': 0.55407834, 'accuracy': 0.77915192}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-450
# INFO:tensorflow:Saving checkpoints for 451 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 451, loss = 0.26655
# INFO:tensorflow:Saving checkpoints for 475 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.189166.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:58:59
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-475
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:59:41
# INFO:tensorflow:Saving dict for global step 475: accuracy = 0.751767, global_step = 475, loss = 0.646556
# {'global_step': 475, 'loss': 0.64655584, 'accuracy': 0.7517668}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-475
# INFO:tensorflow:Saving checkpoints for 476 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 476, loss = 0.213841
# INFO:tensorflow:Saving checkpoints for 500 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.288909.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:04:48
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-500
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:05:30
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.764134, global_step = 500, loss = 0.615492
# {'global_step': 500, 'loss': 0.61549163, 'accuracy': 0.76413429}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-500
# INFO:tensorflow:Saving checkpoints for 501 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 501, loss = 0.263518
# INFO:tensorflow:Saving checkpoints for 525 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.245697.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:10:47
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-525
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:11:27
# INFO:tensorflow:Saving dict for global step 525: accuracy = 0.628975, global_step = 525, loss = 1.0185
# {'global_step': 525, 'loss': 1.0185009, 'accuracy': 0.62897527}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-525
# INFO:tensorflow:Saving checkpoints for 526 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 526, loss = 0.286832
# INFO:tensorflow:Saving checkpoints for 550 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.221972.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:16:44
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-550
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:17:25
# INFO:tensorflow:Saving dict for global step 550: accuracy = 0.784452, global_step = 550, loss = 0.547664
# {'global_step': 550, 'loss': 0.54766411, 'accuracy': 0.78445232}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-550
# INFO:tensorflow:Saving checkpoints for 551 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 551, loss = 0.236044
# INFO:tensorflow:Saving checkpoints for 575 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.257044.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:22:37
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-575
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:23:17
# INFO:tensorflow:Saving dict for global step 575: accuracy = 0.726148, global_step = 575, loss = 0.678414
# {'global_step': 575, 'loss': 0.67841405, 'accuracy': 0.72614843}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-575
# INFO:tensorflow:Saving checkpoints for 576 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 576, loss = 0.32032
# INFO:tensorflow:Saving checkpoints for 600 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.281276.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:28:42
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-600
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:29:23
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.777385, global_step = 600, loss = 0.593352
# {'global_step': 600, 'loss': 0.59335154, 'accuracy': 0.77738518}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-600
# INFO:tensorflow:Saving checkpoints for 601 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 601, loss = 0.247301
# INFO:tensorflow:Saving checkpoints for 625 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.282618.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:34:29
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-625
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:35:11
# INFO:tensorflow:Saving dict for global step 625: accuracy = 0.795053, global_step = 625, loss = 0.551042
# {'global_step': 625, 'loss': 0.5510419, 'accuracy': 0.79505301}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-625
# INFO:tensorflow:Saving checkpoints for 626 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 626, loss = 0.212615
# INFO:tensorflow:Saving checkpoints for 650 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.246437.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:40:25
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-650
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:41:05
# INFO:tensorflow:Saving dict for global step 650: accuracy = 0.786219, global_step = 650, loss = 0.587375
# {'global_step': 650, 'loss': 0.58737457, 'accuracy': 0.78621906}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-650
# INFO:tensorflow:Saving checkpoints for 651 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 651, loss = 0.274733
# INFO:tensorflow:Saving checkpoints for 675 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.18027.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:46:22
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-675
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:47:03
# INFO:tensorflow:Saving dict for global step 675: accuracy = 0.805654, global_step = 675, loss = 0.589455
# {'global_step': 675, 'loss': 0.58945489, 'accuracy': 0.80565369}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-675
# INFO:tensorflow:Saving checkpoints for 676 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 676, loss = 0.176714
# INFO:tensorflow:Saving checkpoints for 700 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.291157.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:52:12
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-700
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:52:53
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.780035, global_step = 700, loss = 0.544111
# {'global_step': 700, 'loss': 0.54411113, 'accuracy': 0.78003532}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-700
# INFO:tensorflow:Saving checkpoints for 701 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 701, loss = 0.236972
# INFO:tensorflow:Saving checkpoints for 725 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.291008.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:58:13
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-725
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:58:55
# INFO:tensorflow:Saving dict for global step 725: accuracy = 0.649293, global_step = 725, loss = 1.17918
# {'global_step': 725, 'loss': 1.179183, 'accuracy': 0.6492933}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-725
# INFO:tensorflow:Saving checkpoints for 726 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 726, loss = 0.261076
# INFO:tensorflow:Saving checkpoints for 750 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.245318.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:04:01
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-750
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:04:43
# INFO:tensorflow:Saving dict for global step 750: accuracy = 0.761484, global_step = 750, loss = 0.604787
# {'global_step': 750, 'loss': 0.60478687, 'accuracy': 0.76148409}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-750
# INFO:tensorflow:Saving checkpoints for 751 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 751, loss = 0.332962
# INFO:tensorflow:Saving checkpoints for 775 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.204163.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:10:00
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-775
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:10:39
# INFO:tensorflow:Saving dict for global step 775: accuracy = 0.733216, global_step = 775, loss = 0.696856
# {'global_step': 775, 'loss': 0.69685626, 'accuracy': 0.73321557}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-775
# INFO:tensorflow:Saving checkpoints for 776 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 776, loss = 0.247768
# INFO:tensorflow:Saving checkpoints for 800 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.18746.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:15:51
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-800
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:16:32
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.771201, global_step = 800, loss = 0.627742
# {'global_step': 800, 'loss': 0.62774223, 'accuracy': 0.77120143}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-800
# INFO:tensorflow:Saving checkpoints for 801 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 801, loss = 0.27002
# INFO:tensorflow:Saving checkpoints for 825 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.324762.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:21:41
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-825
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:22:22
# INFO:tensorflow:Saving dict for global step 825: accuracy = 0.742049, global_step = 825, loss = 0.774455
# {'global_step': 825, 'loss': 0.77445531, 'accuracy': 0.74204946}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-825
# INFO:tensorflow:Saving checkpoints for 826 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 826, loss = 0.266411
# INFO:tensorflow:Saving checkpoints for 850 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.20932.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:28:01
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-850
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:28:42
# INFO:tensorflow:Saving dict for global step 850: accuracy = 0.753534, global_step = 850, loss = 0.632745
# {'global_step': 850, 'loss': 0.63274515, 'accuracy': 0.75353354}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-850
# INFO:tensorflow:Saving checkpoints for 851 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 851, loss = 0.136858
# INFO:tensorflow:Saving checkpoints for 875 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.175123.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:33:46
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-875
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:34:28
# INFO:tensorflow:Saving dict for global step 875: accuracy = 0.746466, global_step = 875, loss = 0.700658
# {'global_step': 875, 'loss': 0.70065802, 'accuracy': 0.74646646}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-875
# INFO:tensorflow:Saving checkpoints for 876 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 876, loss = 0.279181
# INFO:tensorflow:Saving checkpoints for 900 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.241334.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:39:44
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-900
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:40:25
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.741166, global_step = 900, loss = 0.789058
# {'global_step': 900, 'loss': 0.78905815, 'accuracy': 0.74116606}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-900
# INFO:tensorflow:Saving checkpoints for 901 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 901, loss = 0.154852
# INFO:tensorflow:Saving checkpoints for 925 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.303316.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:45:38
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-925
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:46:19
# INFO:tensorflow:Saving dict for global step 925: accuracy = 0.748233, global_step = 925, loss = 0.711812
# {'global_step': 925, 'loss': 0.71181196, 'accuracy': 0.7482332}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-925
# INFO:tensorflow:Saving checkpoints for 926 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 926, loss = 0.233669
# INFO:tensorflow:Saving checkpoints for 950 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.195338.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:51:31
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-950
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:52:11
# INFO:tensorflow:Saving dict for global step 950: accuracy = 0.767668, global_step = 950, loss = 0.656509
# {'global_step': 950, 'loss': 0.65650898, 'accuracy': 0.76766783}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-950
# INFO:tensorflow:Saving checkpoints for 951 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 951, loss = 0.141531
# INFO:tensorflow:Saving checkpoints for 975 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.237316.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:57:33
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-975
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:58:14
# INFO:tensorflow:Saving dict for global step 975: accuracy = 0.771201, global_step = 975, loss = 0.590466
# {'global_step': 975, 'loss': 0.5904665, 'accuracy': 0.77120143}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-975
# INFO:tensorflow:Saving checkpoints for 976 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 976, loss = 0.390181
# INFO:tensorflow:Saving checkpoints for 1000 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.243839.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:03:21
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:04:03
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.736749, global_step = 1000, loss = 0.82226
# {'global_step': 1000, 'loss': 0.82225984, 'accuracy': 0.73674911}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1000
# INFO:tensorflow:Saving checkpoints for 1001 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1001, loss = 0.289197
# INFO:tensorflow:Saving checkpoints for 1025 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.297832.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:09:20
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1025
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:09:57
# INFO:tensorflow:Saving dict for global step 1025: accuracy = 0.717314, global_step = 1025, loss = 0.832995
# {'global_step': 1025, 'loss': 0.83299518, 'accuracy': 0.71731448}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1025
# INFO:tensorflow:Saving checkpoints for 1026 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1026, loss = 0.291874
# INFO:tensorflow:Saving checkpoints for 1050 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.210651.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:15:13
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1050
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:15:53
# INFO:tensorflow:Saving dict for global step 1050: accuracy = 0.726148, global_step = 1050, loss = 0.784328
# {'global_step': 1050, 'loss': 0.78432786, 'accuracy': 0.72614843}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1050
# INFO:tensorflow:Saving checkpoints for 1051 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1051, loss = 0.285185
# INFO:tensorflow:Saving checkpoints for 1075 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.316527.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:21:01
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1075
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:21:42
# INFO:tensorflow:Saving dict for global step 1075: accuracy = 0.795936, global_step = 1075, loss = 0.644164
# {'global_step': 1075, 'loss': 0.64416438, 'accuracy': 0.79593641}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1075
# INFO:tensorflow:Saving checkpoints for 1076 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1076, loss = 0.240097
# INFO:tensorflow:Saving checkpoints for 1100 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.266993.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:27:03
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1100
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:27:43
# INFO:tensorflow:Saving dict for global step 1100: accuracy = 0.783569, global_step = 1100, loss = 0.620352
# {'global_step': 1100, 'loss': 0.62035167, 'accuracy': 0.78356892}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1100
# INFO:tensorflow:Saving checkpoints for 1101 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1101, loss = 0.198835
# INFO:tensorflow:Saving checkpoints for 1125 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.248501.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:32:52
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1125
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:33:34
# INFO:tensorflow:Saving dict for global step 1125: accuracy = 0.787102, global_step = 1125, loss = 0.654671
# {'global_step': 1125, 'loss': 0.65467131, 'accuracy': 0.78710246}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1125
# INFO:tensorflow:Saving checkpoints for 1126 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1126, loss = 0.160316
# INFO:tensorflow:Saving checkpoints for 1150 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.190772.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:38:49
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1150
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:39:26
# INFO:tensorflow:Saving dict for global step 1150: accuracy = 0.805654, global_step = 1150, loss = 0.623841
# {'global_step': 1150, 'loss': 0.62384099, 'accuracy': 0.80565369}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1150
# INFO:tensorflow:Saving checkpoints for 1151 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1151, loss = 0.238638
# INFO:tensorflow:Saving checkpoints for 1175 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.184816.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:44:44
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1175
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:45:24
# INFO:tensorflow:Saving dict for global step 1175: accuracy = 0.803004, global_step = 1175, loss = 0.55416
# {'global_step': 1175, 'loss': 0.55415964, 'accuracy': 0.80300355}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1175
# INFO:tensorflow:Saving checkpoints for 1176 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1176, loss = 0.216375
# INFO:tensorflow:Saving checkpoints for 1200 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.100796.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:50:32
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1200
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:51:13
# INFO:tensorflow:Saving dict for global step 1200: accuracy = 0.787986, global_step = 1200, loss = 0.643326
# {'global_step': 1200, 'loss': 0.6433261, 'accuracy': 0.78798586}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1200
# INFO:tensorflow:Saving checkpoints for 1201 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1201, loss = 0.228121
# INFO:tensorflow:Saving checkpoints for 1225 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.230441.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:56:35
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1225
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:57:15
# INFO:tensorflow:Saving dict for global step 1225: accuracy = 0.728799, global_step = 1225, loss = 0.776985
# {'global_step': 1225, 'loss': 0.77698505, 'accuracy': 0.72879857}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1225
# INFO:tensorflow:Saving checkpoints for 1226 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1226, loss = 0.204342
# INFO:tensorflow:Saving checkpoints for 1250 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.246689.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:02:23
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1250
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:03:06
# INFO:tensorflow:Saving dict for global step 1250: accuracy = 0.765901, global_step = 1250, loss = 0.643915
# {'global_step': 1250, 'loss': 0.64391506, 'accuracy': 0.76590109}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1250
# INFO:tensorflow:Saving checkpoints for 1251 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1251, loss = 0.315286
# INFO:tensorflow:Saving checkpoints for 1275 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.213698.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:08:21
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1275
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:08:58
# INFO:tensorflow:Saving dict for global step 1275: accuracy = 0.80477, global_step = 1275, loss = 0.622956
# {'global_step': 1275, 'loss': 0.62295616, 'accuracy': 0.80477029}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1275
# INFO:tensorflow:Saving checkpoints for 1276 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1276, loss = 0.198984
# INFO:tensorflow:Saving checkpoints for 1300 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.199881.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:14:15
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1300
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:14:56
# INFO:tensorflow:Saving dict for global step 1300: accuracy = 0.780035, global_step = 1300, loss = 0.697371
# {'global_step': 1300, 'loss': 0.69737095, 'accuracy': 0.78003532}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1300
# INFO:tensorflow:Saving checkpoints for 1301 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1301, loss = 0.246874
# INFO:tensorflow:Saving checkpoints for 1325 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.209272.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:20:04
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1325
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:20:44
# INFO:tensorflow:Saving dict for global step 1325: accuracy = 0.743816, global_step = 1325, loss = 0.843708
# {'global_step': 1325, 'loss': 0.8437075, 'accuracy': 0.74381626}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1325
# INFO:tensorflow:Saving checkpoints for 1326 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1326, loss = 0.171036
# INFO:tensorflow:Saving checkpoints for 1350 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.20252.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:26:06
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1350
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:26:47
# INFO:tensorflow:Saving dict for global step 1350: accuracy = 0.771201, global_step = 1350, loss = 0.70048
# {'global_step': 1350, 'loss': 0.70048022, 'accuracy': 0.77120143}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1350
# INFO:tensorflow:Saving checkpoints for 1351 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1351, loss = 0.29546
# INFO:tensorflow:Saving checkpoints for 1375 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.249816.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:31:55
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1375
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:32:37
# INFO:tensorflow:Saving dict for global step 1375: accuracy = 0.770318, global_step = 1375, loss = 0.659827
# {'global_step': 1375, 'loss': 0.65982658, 'accuracy': 0.77031803}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1375
# INFO:tensorflow:Saving checkpoints for 1376 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1376, loss = 0.172288
# INFO:tensorflow:Saving checkpoints for 1400 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.269885.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:37:53
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1400
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:38:34
# INFO:tensorflow:Saving dict for global step 1400: accuracy = 0.801237, global_step = 1400, loss = 0.658152
# {'global_step': 1400, 'loss': 0.65815151, 'accuracy': 0.80123675}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1400
# INFO:tensorflow:Saving checkpoints for 1401 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1401, loss = 0.200281
# INFO:tensorflow:Saving checkpoints for 1425 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.222753.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:43:48
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1425
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:44:30
# INFO:tensorflow:Saving dict for global step 1425: accuracy = 0.793286, global_step = 1425, loss = 0.735733
# {'global_step': 1425, 'loss': 0.73573261, 'accuracy': 0.7932862}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1425
# INFO:tensorflow:Saving checkpoints for 1426 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1426, loss = 0.196421
# INFO:tensorflow:Saving checkpoints for 1450 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.356403.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:49:38
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1450
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:50:18
# INFO:tensorflow:Saving dict for global step 1450: accuracy = 0.793286, global_step = 1450, loss = 0.609837
# {'global_step': 1450, 'loss': 0.60983717, 'accuracy': 0.7932862}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1450
# INFO:tensorflow:Saving checkpoints for 1451 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1451, loss = 0.186491
# INFO:tensorflow:Saving checkpoints for 1475 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.219557.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:55:43
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1475
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:56:25
# INFO:tensorflow:Saving dict for global step 1475: accuracy = 0.774735, global_step = 1475, loss = 0.723055
# {'global_step': 1475, 'loss': 0.72305453, 'accuracy': 0.77473497}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1475
# INFO:tensorflow:Saving checkpoints for 1476 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1476, loss = 0.328478
# INFO:tensorflow:Saving checkpoints for 1500 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.256346.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:01:33
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1500
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:02:14
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.739399, global_step = 1500, loss = 0.795643
# {'global_step': 1500, 'loss': 0.79564345, 'accuracy': 0.73939931}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1500
# INFO:tensorflow:Saving checkpoints for 1501 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1501, loss = 0.210478
# INFO:tensorflow:Saving checkpoints for 1525 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.133889.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:07:33
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1525
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:08:13
# INFO:tensorflow:Saving dict for global step 1525: accuracy = 0.763251, global_step = 1525, loss = 0.845738
# {'global_step': 1525, 'loss': 0.84573829, 'accuracy': 0.76325089}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1525
# INFO:tensorflow:Saving checkpoints for 1526 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1526, loss = 0.301065
# INFO:tensorflow:Saving checkpoints for 1550 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.325936.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:13:33
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1550
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:14:14
# INFO:tensorflow:Saving dict for global step 1550: accuracy = 0.814488, global_step = 1550, loss = 0.636184
# {'global_step': 1550, 'loss': 0.63618362, 'accuracy': 0.81448764}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1550
# INFO:tensorflow:Saving checkpoints for 1551 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1551, loss = 0.17892
# INFO:tensorflow:Saving checkpoints for 1575 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.164279.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:19:25
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1575
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:20:06
# INFO:tensorflow:Saving dict for global step 1575: accuracy = 0.772085, global_step = 1575, loss = 0.794641
# {'global_step': 1575, 'loss': 0.79464096, 'accuracy': 0.77208483}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1575
# INFO:tensorflow:Saving checkpoints for 1576 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1576, loss = 0.231763
# INFO:tensorflow:Saving checkpoints for 1600 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.327128.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:25:26
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1600
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:26:07
# INFO:tensorflow:Saving dict for global step 1600: accuracy = 0.810071, global_step = 1600, loss = 0.637104
# {'global_step': 1600, 'loss': 0.6371038, 'accuracy': 0.81007069}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1600
# INFO:tensorflow:Saving checkpoints for 1601 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1601, loss = 0.154116
# INFO:tensorflow:Saving checkpoints for 1625 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13889.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:31:12
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1625
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:31:53
# INFO:tensorflow:Saving dict for global step 1625: accuracy = 0.806537, global_step = 1625, loss = 0.713499
# {'global_step': 1625, 'loss': 0.71349931, 'accuracy': 0.80653709}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1625
# INFO:tensorflow:Saving checkpoints for 1626 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1626, loss = 0.145731
# INFO:tensorflow:Saving checkpoints for 1650 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.150204.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:37:09
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1650
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:37:50
# INFO:tensorflow:Saving dict for global step 1650: accuracy = 0.80477, global_step = 1650, loss = 0.672709
# {'global_step': 1650, 'loss': 0.67270851, 'accuracy': 0.80477029}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1650
# INFO:tensorflow:Saving checkpoints for 1651 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1651, loss = 0.175064
# INFO:tensorflow:Saving checkpoints for 1675 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.143372.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:43:01
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1675
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:43:42
# INFO:tensorflow:Saving dict for global step 1675: accuracy = 0.753534, global_step = 1675, loss = 0.886204
# {'global_step': 1675, 'loss': 0.88620383, 'accuracy': 0.75353354}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1675
# INFO:tensorflow:Saving checkpoints for 1676 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1676, loss = 0.272166
# INFO:tensorflow:Saving checkpoints for 1700 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.303219.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:48:49
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1700
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:49:30
# ...
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1950
# INFO:tensorflow:Finished evaluation at 2017-11-28-13:48:41
# INFO:tensorflow:Saving dict for global step 1950: accuracy = 0.762367, global_step = 1950, loss = 0.818381
# {'global_step': 1950, 'loss': 0.81838089, 'accuracy': 0.76236749}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1950
# INFO:tensorflow:Saving checkpoints for 1951 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1951, loss = 0.343025
# INFO:tensorflow:Saving checkpoints for 1975 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.254529.
# INFO:tensorflow:Starting evaluation at 2017-11-28-13:54:01
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1975
# INFO:tensorflow:Finished evaluation at 2017-11-28-13:54:43
# INFO:tensorflow:Saving dict for global step 1975: accuracy = 0.780035, global_step = 1975, loss = 0.637975
# {'global_step': 1975, 'loss': 0.63797539, 'accuracy': 0.78003532}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-1975
# INFO:tensorflow:Saving checkpoints for 1976 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 1976, loss = 0.237265
# INFO:tensorflow:Saving checkpoints for 2000 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.280458.
# INFO:tensorflow:Starting evaluation at 2017-11-28-13:59:46
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2000
# INFO:tensorflow:Finished evaluation at 2017-11-28-14:00:27
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.795053, global_step = 2000, loss = 0.670325
# {'global_step': 2000, 'loss': 0.67032486, 'accuracy': 0.79505301}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2000
# INFO:tensorflow:Saving checkpoints for 2001 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2001, loss = 0.18091
# INFO:tensorflow:Saving checkpoints for 2025 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.167477.
# INFO:tensorflow:Starting evaluation at 2017-11-28-14:05:43
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2025
# INFO:tensorflow:Finished evaluation at 2017-11-28-14:06:24
# INFO:tensorflow:Saving dict for global step 2025: accuracy = 0.819788, global_step = 2025, loss = 0.645963
# {'global_step': 2025, 'loss': 0.64596277, 'accuracy': 0.81978798}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2025
# INFO:tensorflow:Saving checkpoints for 2026 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2026, loss = 0.218807
# INFO:tensorflow:Saving checkpoints for 2050 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.270732.
# INFO:tensorflow:Starting evaluation at 2017-11-28-14:11:33
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2050
# INFO:tensorflow:Finished evaluation at 2017-11-28-14:12:14
# INFO:tensorflow:Saving dict for global step 2050: accuracy = 0.751767, global_step = 2050, loss = 0.850161
# {'global_step': 2050, 'loss': 0.85016066, 'accuracy': 0.7517668}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2050
# INFO:tensorflow:Saving checkpoints for 2051 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2051, loss = 0.173319
# INFO:tensorflow:Saving checkpoints for 2075 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.169938.
# INFO:tensorflow:Starting evaluation at 2017-11-28-14:17:25
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2075
# INFO:tensorflow:Finished evaluation at 2017-11-28-14:18:06
# INFO:tensorflow:Saving dict for global step 2075: accuracy = 0.771201, global_step = 2075, loss = 0.705156
# {'global_step': 2075, 'loss': 0.70515555, 'accuracy': 0.77120143}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2075
# INFO:tensorflow:Saving checkpoints for 2076 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2076, loss = 0.23082
# INFO:tensorflow:Saving checkpoints for 2100 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.19535.
# INFO:tensorflow:Starting evaluation at 2017-11-28-14:23:26
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2100
# INFO:tensorflow:Finished evaluation at 2017-11-28-14:24:09
# INFO:tensorflow:Saving dict for global step 2100: accuracy = 0.801237, global_step = 2100, loss = 0.651823
# {'global_step': 2100, 'loss': 0.6518234, 'accuracy': 0.80123675}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2100
# INFO:tensorflow:Saving checkpoints for 2101 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2101, loss = 0.217104
# INFO:tensorflow:Saving checkpoints for 2125 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.203387.
# INFO:tensorflow:Starting evaluation at 2017-11-28-14:29:14
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2125
# INFO:tensorflow:Finished evaluation at 2017-11-28-14:29:55
# INFO:tensorflow:Saving dict for global step 2125: accuracy = 0.787986, global_step = 2125, loss = 0.772984
# {'global_step': 2125, 'loss': 0.77298373, 'accuracy': 0.78798586}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2125
# INFO:tensorflow:Saving checkpoints for 2126 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2126, loss = 0.153688
# INFO:tensorflow:Saving checkpoints for 2150 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.172299.
# INFO:tensorflow:Starting evaluation at 2017-11-28-14:35:13
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2150
# INFO:tensorflow:Finished evaluation at 2017-11-28-14:35:54
# INFO:tensorflow:Saving dict for global step 2150: accuracy = 0.80742, global_step = 2150, loss = 0.671215
# {'global_step': 2150, 'loss': 0.6712153, 'accuracy': 0.80742049}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2150
# INFO:tensorflow:Saving checkpoints for 2151 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2151, loss = 0.133468
# INFO:tensorflow:Saving checkpoints for 2175 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.248641.
# INFO:tensorflow:Starting evaluation at 2017-11-28-14:41:03
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2175
# INFO:tensorflow:Finished evaluation at 2017-11-28-14:41:44
# INFO:tensorflow:Saving dict for global step 2175: accuracy = 0.746466, global_step = 2175, loss = 0.922517
# {'global_step': 2175, 'loss': 0.9225167, 'accuracy': 0.74646646}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2175
# INFO:tensorflow:Saving checkpoints for 2176 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2176, loss = 0.362791
# INFO:tensorflow:Saving checkpoints for 2200 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.219256.
# INFO:tensorflow:Starting evaluation at 2017-11-28-15:37:06
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2200
# INFO:tensorflow:Finished evaluation at 2017-11-28-15:37:51
# INFO:tensorflow:Saving dict for global step 2200: accuracy = 0.780035, global_step = 2200, loss = 0.619919
# {'global_step': 2200, 'loss': 0.619919, 'accuracy': 0.78003532}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2200
# INFO:tensorflow:Saving checkpoints for 2201 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2201, loss = 0.206153
# INFO:tensorflow:Saving checkpoints for 2225 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.224305.
# INFO:tensorflow:Starting evaluation at 2017-11-28-15:43:37
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2225
# INFO:tensorflow:Finished evaluation at 2017-11-28-15:44:19
# INFO:tensorflow:Saving dict for global step 2225: accuracy = 0.767668, global_step = 2225, loss = 0.746456
# {'global_step': 2225, 'loss': 0.74645615, 'accuracy': 0.76766783}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2225
# INFO:tensorflow:Saving checkpoints for 2226 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2226, loss = 0.199411
# INFO:tensorflow:Saving checkpoints for 2250 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.247418.
# INFO:tensorflow:Starting evaluation at 2017-11-28-15:49:37
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2250
# INFO:tensorflow:Finished evaluation at 2017-11-28-15:50:19
# INFO:tensorflow:Saving dict for global step 2250: accuracy = 0.801237, global_step = 2250, loss = 0.628751
# {'global_step': 2250, 'loss': 0.62875056, 'accuracy': 0.80123675}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2250
# INFO:tensorflow:Saving checkpoints for 2251 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2251, loss = 0.204831
# INFO:tensorflow:Saving checkpoints for 2275 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.263721.
# INFO:tensorflow:Starting evaluation at 2017-11-28-15:56:13
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2275
# INFO:tensorflow:Finished evaluation at 2017-11-28-15:56:50
# INFO:tensorflow:Saving dict for global step 2275: accuracy = 0.800353, global_step = 2275, loss = 0.739417
# {'global_step': 2275, 'loss': 0.73941654, 'accuracy': 0.80035335}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2275
# INFO:tensorflow:Saving checkpoints for 2276 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2276, loss = 0.227126
# INFO:tensorflow:Saving checkpoints for 2300 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.270257.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:02:58
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2300
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:03:58
# INFO:tensorflow:Saving dict for global step 2300: accuracy = 0.808304, global_step = 2300, loss = 0.631502
# {'global_step': 2300, 'loss': 0.63150239, 'accuracy': 0.80830389}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2300
# INFO:tensorflow:Saving checkpoints for 2301 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2301, loss = 0.193164
# INFO:tensorflow:Saving checkpoints for 2325 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.238786.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:09:37
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2325
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:10:16
# INFO:tensorflow:Saving dict for global step 2325: accuracy = 0.801237, global_step = 2325, loss = 0.699511
# {'global_step': 2325, 'loss': 0.69951069, 'accuracy': 0.80123675}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2325
# INFO:tensorflow:Saving checkpoints for 2326 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2326, loss = 0.286822
# INFO:tensorflow:Saving checkpoints for 2350 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.231611.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:15:46
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2350
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:16:28
# INFO:tensorflow:Saving dict for global step 2350: accuracy = 0.818021, global_step = 2350, loss = 0.677049
# {'global_step': 2350, 'loss': 0.67704862, 'accuracy': 0.81802118}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2350
# INFO:tensorflow:Saving checkpoints for 2351 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2351, loss = 0.240158
# INFO:tensorflow:Saving checkpoints for 2375 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.271765.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:21:56
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2375
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:22:40
# INFO:tensorflow:Saving dict for global step 2375: accuracy = 0.79417, global_step = 2375, loss = 0.82109
# {'global_step': 2375, 'loss': 0.82108951, 'accuracy': 0.7941696}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2375
# INFO:tensorflow:Saving checkpoints for 2376 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2376, loss = 0.138643
# INFO:tensorflow:Saving checkpoints for 2400 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.23125.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:28:07
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2400
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:28:44
# INFO:tensorflow:Saving dict for global step 2400: accuracy = 0.787986, global_step = 2400, loss = 0.735089
# {'global_step': 2400, 'loss': 0.73508948, 'accuracy': 0.78798586}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2400
# INFO:tensorflow:Saving checkpoints for 2401 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2401, loss = 0.164756
# INFO:tensorflow:Saving checkpoints for 2425 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.194385.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:34:05
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2425
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:34:47
# INFO:tensorflow:Saving dict for global step 2425: accuracy = 0.757067, global_step = 2425, loss = 0.811769
# {'global_step': 2425, 'loss': 0.81176865, 'accuracy': 0.75706714}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2425
# INFO:tensorflow:Saving checkpoints for 2426 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2426, loss = 0.262544
# INFO:tensorflow:Saving checkpoints for 2450 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.166623.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:40:10
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2450
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:40:50
# INFO:tensorflow:Saving dict for global step 2450: accuracy = 0.759717, global_step = 2450, loss = 0.83052
# {'global_step': 2450, 'loss': 0.83052039, 'accuracy': 0.75971729}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2450
# INFO:tensorflow:Saving checkpoints for 2451 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2451, loss = 0.204043
# INFO:tensorflow:Saving checkpoints for 2475 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.266909.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:46:24
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2475
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:47:09
# INFO:tensorflow:Saving dict for global step 2475: accuracy = 0.7553, global_step = 2475, loss = 0.725213
# {'global_step': 2475, 'loss': 0.72521329, 'accuracy': 0.75530034}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2475
# INFO:tensorflow:Saving checkpoints for 2476 into models/cnn/model.ckpt.
# INFO:tensorflow:step = 2476, loss = 0.285277
# INFO:tensorflow:Saving checkpoints for 2500 into models/cnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.233157.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:52:23
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2500
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:53:07
# INFO:tensorflow:Saving dict for global step 2500: accuracy = 0.803004, global_step = 2500, loss = 0.734261
# {'global_step': 2500, 'loss': 0.73426104, 'accuracy': 0.80300355}
# INFO:tensorflow:Restoring parameters from models/cnn/model.ckpt-2500

# %%
# Run network
pred = main(X_train, Y_train, X_valid, Y_valid, X_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_model_dir': 'models-test-estimator/', '_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_session_config': None, '_log_step_count_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 60.3213, step = 1
# INFO:tensorflow:Saving checkpoints for 72 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 100 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.895572.
# INFO:tensorflow:Starting evaluation at 2017-11-19-22:33:41
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-100
# INFO:tensorflow:Finished evaluation at 2017-11-19-22:34:02
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.720848, global_step = 100, loss = 1.18861
# {'loss': 1.1886137, 'global_step': 100, 'accuracy': 0.72084808}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-100
# INFO:tensorflow:Saving checkpoints for 101 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.900437, step = 101
# INFO:tensorflow:Saving checkpoints for 131 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 200 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.273767.
# INFO:tensorflow:Starting evaluation at 2017-11-20-00:18:03
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-200
# INFO:tensorflow:Finished evaluation at 2017-11-20-00:18:26
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.797703, global_step = 200, loss = 0.516123
# {'loss': 0.51612258, 'global_step': 200, 'accuracy': 0.79770321}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-200
# INFO:tensorflow:Saving checkpoints for 201 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.27112, step = 201
# INFO:tensorflow:Saving checkpoints for 261 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 300 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.273135.
# INFO:tensorflow:Starting evaluation at 2017-11-20-00:35:26
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-300
# INFO:tensorflow:Finished evaluation at 2017-11-20-00:35:55
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.789753, global_step = 300, loss = 0.55483
# {'loss': 0.55483007, 'global_step': 300, 'accuracy': 0.78975266}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-300
# INFO:tensorflow:Saving checkpoints for 301 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.186627, step = 301
# INFO:tensorflow:Saving checkpoints for 363 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 400 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.261198.
# INFO:tensorflow:Starting evaluation at 2017-11-20-00:51:48
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-400
# INFO:tensorflow:Finished evaluation at 2017-11-20-00:52:11
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.742933, global_step = 400, loss = 0.545087
# {'loss': 0.54508698, 'global_step': 400, 'accuracy': 0.74293286}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-400
# INFO:tensorflow:Saving checkpoints for 401 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.299955, step = 401
# INFO:tensorflow:Saving checkpoints for 468 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 500 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.257225.
# INFO:tensorflow:Starting evaluation at 2017-11-20-01:07:35
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-500
# INFO:tensorflow:Finished evaluation at 2017-11-20-01:08:00
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.806537, global_step = 500, loss = 0.515962
# {'loss': 0.51596189, 'global_step': 500, 'accuracy': 0.80653709}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-500
# INFO:tensorflow:Saving checkpoints for 501 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.228074, step = 501
# INFO:tensorflow:Saving checkpoints for 561 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 600 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.211994.
# INFO:tensorflow:Starting evaluation at 2017-11-20-01:23:49
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-600
# INFO:tensorflow:Finished evaluation at 2017-11-20-01:24:10
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.805654, global_step = 600, loss = 0.519708
# {'loss': 0.5197084, 'global_step': 600, 'accuracy': 0.80565369}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-600
# INFO:tensorflow:Saving checkpoints for 601 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.199173, step = 601
# INFO:tensorflow:Saving checkpoints for 670 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 700 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.180829.
# INFO:tensorflow:Starting evaluation at 2017-11-20-01:39:29
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-700
# INFO:tensorflow:Finished evaluation at 2017-11-20-01:39:57
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.742933, global_step = 700, loss = 0.641556
# {'loss': 0.64155644, 'global_step': 700, 'accuracy': 0.74293286}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-700
# INFO:tensorflow:Saving checkpoints for 701 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.206732, step = 701
# INFO:tensorflow:Saving checkpoints for 757 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 800 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.293789.
# INFO:tensorflow:Starting evaluation at 2017-11-20-01:59:18
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-800
# INFO:tensorflow:Finished evaluation at 2017-11-20-01:59:45
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.766784, global_step = 800, loss = 0.604053
# {'loss': 0.60405266, 'global_step': 800, 'accuracy': 0.76678443}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-800
# INFO:tensorflow:Saving checkpoints for 801 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.199741, step = 801
# INFO:tensorflow:Saving checkpoints for 858 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 900 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.189586.
# INFO:tensorflow:Starting evaluation at 2017-11-20-02:18:20
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-900
# INFO:tensorflow:Finished evaluation at 2017-11-20-02:18:51
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.795936, global_step = 900, loss = 0.613583
# {'loss': 0.61358339, 'global_step': 900, 'accuracy': 0.79593641}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-900
# INFO:tensorflow:Saving checkpoints for 901 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.207821, step = 901
# INFO:tensorflow:Saving checkpoints for 958 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1000 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.275022.
# INFO:tensorflow:Starting evaluation at 2017-11-20-02:36:28
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-20-02:36:52
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.783569, global_step = 1000, loss = 0.608566
# {'loss': 0.60856622, 'global_step': 1000, 'accuracy': 0.78356892}
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-1000

# %%
import numpy as np
import tensorflow as tf
x = [5, 5, 64]
x.extend([1])

x[3], x[2] = x[2], x[3]
print(x)
# Out:
# [5, 5, 1, 64]

# %%
x=np.zeros([2,3,4])
x.size // x.shape[0]
# Out:
# 12
