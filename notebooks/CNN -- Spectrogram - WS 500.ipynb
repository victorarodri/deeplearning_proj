# %%
# Imports
import tensorflow as tf
import numpy as np
import glob
import csv
import os
import random

# %%
# Access data
def get_data(data_dir, labels_path):
    data_filenames = glob.glob(os.path.join(data_dir, '*npy'))
    random.shuffle(data_filenames)

    num_examples = len(data_filenames)
    
    labels_dict = {}
    get_labels_dict(labels_path, labels_dict)
    
    X = np.zeros([num_examples, 251, 100])
    Y = np.zeros(num_examples)
    for i, df in enumerate(data_filenames):
        X[i, :, :] = np.load(df)
        
        label_key = df.split('/')[-1].split('.')[0].split('_')[0]
        Y[i] = labels_dict[label_key]
        
    # Convert -1 labels to 0
    Y[np.where(Y == -1)] = 0
        
    return X.astype(np.float32), Y.astype(np.float32)


def get_labels_dict(reference_path, reference):
    with open(reference_path) as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            reference[row[0]] = row[1]

# %%
# Helper functions for defining variables in the network graph
def _variable_on_cpu(name, shape, initializer):
    """
    Helper to create a Variable stored on CPU memory.
    """

    with tf.device('/cpu:0'):
        var = tf.get_variable(
            name=name, 
            shape=shape, 
            dtype=tf.float32, 
            initializer=initializer)

    return var

def _variable_with_weight_decay(name, shape, stddev, wd):
    """
    Helper to create an initialized Variable with weight decay.
    """

    var = _variable_on_cpu(
        name=name,
        shape=shape,
        initializer=tf.truncated_normal_initializer(
            stddev=stddev,
            dtype=tf.float32))

    if wd is not None:
        weight_decay = tf.multiply(tf.nn.l2_loss(var), wd, 
                                   name='weight_loss')
        tf.add_to_collection('losses', weight_decay)

    return var


def loss(unscale_logits, labels):
    """
    Add L2Loss to all the trainable variables.
    """

    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(
        labels=labels,
        logits=unscale_logits,
        name='cross_entropy')

    cross_entropy_mean = tf.reduce_mean(cross_entropy, name='cross_entropy')

    tf.add_to_collection('losses', cross_entropy_mean)

    total_loss = tf.add_n(tf.get_collection('losses'), name='total_loss')

    return total_loss

# %%
# Function for defining CNN network 
# (window size = 300)
def cnn(features):

    # Input Layer.
    input_layer = tf.reshape(features["x"], [-1, 151, 100, 1])

    # Convolutional layer #1.
    with tf.variable_scope(name_or_scope='conv1') as scope:
        kernel = _variable_with_weight_decay(
            name='weights',
            shape=[5, 5, 1, 64],
            stddev=5e-2,
            wd=0.0)

        conv = tf.nn.conv2d(
            input=input_layer,
            filter=kernel,
            strides=[1, 1, 1, 1],
            padding='SAME')

        biases = _variable_on_cpu(
            name='biases',
            shape=[64],
            initializer=tf.constant_initializer(0.0))

        pre_activation = tf.nn.bias_add(conv, biases)

        conv1 = tf.nn.tanh(
            x=pre_activation, 
            name=scope.name)
        
        
    # Max pooling layer #1.
    pool1 = tf.nn.max_pool(
        value=conv1,
        ksize=[1, 3, 3, 1], 
        strides=[1, 2, 2, 1],
        padding='SAME', 
        name='pool1')

    
    # Local response normalization layer #1.
    norm1 = tf.nn.lrn(
        input=pool1, 
        depth_radius=4, 
        bias=1.0, 
        alpha=0.001 / 9.0, 
        beta=0.75,
        name='norm1')
    
    # Convolutional layer #2.
    with tf.variable_scope(name_or_scope='conv2') as scope:
        kernel = _variable_with_weight_decay(
            name='weights',
            shape=[5, 5, 64, 64],
            stddev=5e-2,
            wd=0.0)

        conv = tf.nn.conv2d(
            input=norm1,
            filter=kernel,
            strides=[1, 1, 1, 1],
            padding='SAME')

        biases = _variable_on_cpu(
            name='biases',
            shape=[64],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.nn.bias_add(conv, biases)

        conv2 = tf.nn.tanh(
            x=pre_activation, 
            name=scope.name)

    # Local response normalization layer #2.
    norm2 = tf.nn.lrn(
        input=conv2, 
        depth_radius=4, 
        bias=1.0, 
        alpha=0.001 / 9.0, 
        beta=0.75,
        name='norm2')

    # Max pooling layer #2.
    pool2 = tf.nn.max_pool(
        value=norm2,
        ksize=[1, 3, 3, 1], 
        strides=[1, 2, 2, 1],
        padding='SAME', 
        name='pool2')

    # Fully connected layer #1.
    with tf.variable_scope(name_or_scope='fc1') as scope:
        flat = tf.reshape(pool2, [-1, 60800])

        weights = _variable_with_weight_decay(
            name='weights',
            shape=[60800, 384],
            stddev=0.04,
            wd=0.004)

        biases = _variable_on_cpu(
            name='biases',
            shape=[384],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.add(tf.matmul(flat, weights), biases)

        fc1 = tf.nn.relu(
            features=pre_activation,
            name=scope.name)

        
    # Fully connected layer #2.
    with tf.variable_scope(name_or_scope='fc2') as scope:
        weights = _variable_with_weight_decay(
            name='weights',
            shape=[384, 192],
            stddev=0.04,
            wd=0.004)

        biases = _variable_on_cpu(
            name='biases',
            shape=[192],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.add(tf.matmul(fc1, weights), biases)

        fc2 = tf.nn.relu(
            features=pre_activation,
            name=scope.name)

        
    # Unscaled logits layer #1.
    with tf.variable_scope(name_or_scope='logits1') as scope:
        weights = _variable_with_weight_decay(
            name='weights',
            shape=[192, 2],
            stddev=1.0 / 192.0,
            wd=0.0)

        biases = _variable_on_cpu(
            name='biases',
            shape=[2],
            initializer=tf.constant_initializer(0.0))

        unscale_logits = tf.add(tf.matmul(fc2, weights), biases)
        
    return unscale_logits

# %%
# Function for defining CNN network
# (window size = 500)
def cnn2(features):

    # Input Layer.
    input_layer = tf.reshape(features["x"], [-1, 251, 100, 1])

    # Convolutional layer #1.
    with tf.variable_scope(name_or_scope='conv1') as scope:
        kernel = _variable_with_weight_decay(
            name='weights',
            shape=[5, 5, 1, 64],
            stddev=5e-2,
            wd=0.0)

        conv = tf.nn.conv2d(
            input=input_layer,
            filter=kernel,
            strides=[1, 1, 1, 1],
            padding='SAME')

        biases = _variable_on_cpu(
            name='biases',
            shape=[64],
            initializer=tf.constant_initializer(0.0))

        pre_activation = tf.nn.bias_add(conv, biases)

        conv1 = tf.nn.tanh(
            x=pre_activation, 
            name=scope.name)
        
        
    # Max pooling layer #1.
    pool1 = tf.nn.max_pool(
        value=conv1,
        ksize=[1, 3, 3, 1], 
        strides=[1, 2, 2, 1],
        padding='SAME', 
        name='pool1')

    
    # Local response normalization layer #1.
    norm1 = tf.nn.lrn(
        input=pool1, 
        depth_radius=4, 
        bias=1.0, 
        alpha=0.001 / 9.0, 
        beta=0.75,
        name='norm1')
    
    # Convolutional layer #2.
    with tf.variable_scope(name_or_scope='conv2') as scope:
        kernel = _variable_with_weight_decay(
            name='weights',
            shape=[5, 5, 64, 64],
            stddev=5e-2,
            wd=0.0)

        conv = tf.nn.conv2d(
            input=norm1,
            filter=kernel,
            strides=[1, 1, 1, 1],
            padding='SAME')

        biases = _variable_on_cpu(
            name='biases',
            shape=[64],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.nn.bias_add(conv, biases)

        conv2 = tf.nn.tanh(
            x=pre_activation, 
            name=scope.name)

    # Local response normalization layer #2.
    norm2 = tf.nn.lrn(
        input=conv2, 
        depth_radius=4, 
        bias=1.0, 
        alpha=0.001 / 9.0, 
        beta=0.75,
        name='norm2')

    # Max pooling layer #2.
    pool2 = tf.nn.max_pool(
        value=norm2,
        ksize=[1, 3, 3, 1], 
        strides=[1, 2, 2, 1],
        padding='SAME', 
        name='pool2')

    # Fully connected layer #1.
    with tf.variable_scope(name_or_scope='fc1') as scope:
        flat = tf.reshape(pool2, [-1, 100800])

        weights = _variable_with_weight_decay(
            name='weights',
            shape=[100800, 384],
            stddev=0.04,
            wd=0.004)

        biases = _variable_on_cpu(
            name='biases',
            shape=[384],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.add(tf.matmul(flat, weights), biases)

        fc1 = tf.nn.relu(
            features=pre_activation,
            name=scope.name)

        
    # Fully connected layer #2.
    with tf.variable_scope(name_or_scope='fc2') as scope:
        weights = _variable_with_weight_decay(
            name='weights',
            shape=[384, 192],
            stddev=0.04,
            wd=0.004)

        biases = _variable_on_cpu(
            name='biases',
            shape=[192],
            initializer=tf.constant_initializer(0.1))

        pre_activation = tf.add(tf.matmul(fc1, weights), biases)

        fc2 = tf.nn.relu(
            features=pre_activation,
            name=scope.name)

        
    # Unscaled logits layer #1.
    with tf.variable_scope(name_or_scope='logits1') as scope:
        weights = _variable_with_weight_decay(
            name='weights',
            shape=[192, 2],
            stddev=1.0 / 192.0,
            wd=0.0)

        biases = _variable_on_cpu(
            name='biases',
            shape=[2],
            initializer=tf.constant_initializer(0.0))

        unscale_logits = tf.add(tf.matmul(fc2, weights), biases)
        
    return unscale_logits

# %%
# Function for building CNN network
def cnn_model_fn(features, labels, mode):
    """
    Build model.
    """
    unscale_logits = cnn2(features)
        
    # Generate predictions for PREDICT and EVAL modes.
    predictions = {
        'classes': tf.argmax(input=unscale_logits, axis=1),
        'probabilities': tf.nn.softmax(unscale_logits, name='softmax_tensor')
    }
    
    ####################
    # PREDICT
    ####################
    if mode == tf.estimator.ModeKeys.PREDICT: 
        return tf.estimator.EstimatorSpec(mode=mode, 
                                          predictions=predictions['probabilities'])
    
    else:
        # Calculate loss for both TRAIN and EVAL modes.
        labels = tf.cast(labels, tf.int64)
        total_loss = loss(unscale_logits, labels)

        # Add summary operation for total loss visualizaiton.
        tf.summary.scalar(
            name='total_loss',
            tensor=total_loss)
    

        ####################
        # TRAIN
        ####################
        if mode == tf.estimator.ModeKeys.TRAIN:

            # Compute gradients using Gradient Descent Optimizer.
            optimizer = tf.train.AdamOptimizer()

            grads_vars = optimizer.compute_gradients(loss=total_loss)

            # Add summary operations for gradient visualizations.
            for grad, var in grads_vars:
                if grad is not None:
                    tf.summary.histogram(
                        name=var.op.name + '/gradients', 
                        values=grad)

            train_op = optimizer.minimize(
                loss=total_loss,
                global_step=tf.train.get_global_step())

            # Add evaluation metrics for TRAIN mode.
            accuracy_train = tf.metrics.accuracy(
                labels=labels, 
                predictions=predictions["classes"])

            # Add summary operation for training accuracy visualizaiton.
            tf.summary.scalar(
                name='accuracy_train',
                tensor=accuracy_train[0])

            train_summary_hook = tf.train.SummarySaverHook(
                save_steps=10,
                output_dir='models/cnn2',
                summary_op=tf.summary.merge_all())

            return tf.estimator.EstimatorSpec(
                mode=mode,
                loss=total_loss, 
                train_op=train_op,
                training_hooks=[train_summary_hook])

        
        ####################
        # EVALUATE
        ####################
        else:
            accuracy_valid = tf.metrics.accuracy(
                labels=labels, 
                predictions=predictions["classes"])

            # Add summary operation for validation accuracy visualizaiton.
            tf.summary.scalar(
                name='accuracy_validation',
                tensor=accuracy_valid[0])

            eval_metric_ops = {"accuracy": accuracy_valid}

            eval_summary_hook = tf.train.SummarySaverHook(
                save_steps=1,
                output_dir='models/cnn2',
                summary_op=tf.summary.merge_all())

            return tf.estimator.EstimatorSpec(
                mode=mode, 
                loss=total_loss, 
                eval_metric_ops=eval_metric_ops,
                training_hooks=[eval_summary_hook])

# %%
# Main function for building, training and evaluating model.
def main(train_data, train_labels, eval_data, eval_labels, test_data):
    
    estimator_dir = 'models/cnn2'
    
    # Delete directory containing events logs and checkpoints if it exists.
    if tf.gfile.Exists(estimator_dir):
        tf.gfile.DeleteRecursively(estimator_dir)
        
    # Create directory containing events logs and checkpoints.
    tf.gfile.MakeDirs(estimator_dir)
    
    # Create the Estimator.
    classifier = tf.estimator.Estimator(
        model_fn=cnn_model_fn, 
        model_dir=estimator_dir)

    for _ in range(100):
        
        # Train the model.
        train_input_fn = tf.estimator.inputs.numpy_input_fn(
            x={"x": train_data},
            y=train_labels,
            batch_size=96,
            num_epochs=None,
            shuffle=True)

        classifier.train(
            input_fn=train_input_fn,
            steps=25)

        # Evaluate the model and print results.
        eval_input_fn = tf.estimator.inputs.numpy_input_fn(
            x={"x": eval_data},
            y=eval_labels,
            num_epochs=1,
            shuffle=False)
    
        eval_results = classifier.evaluate(input_fn=eval_input_fn)
        print(eval_results)
        
    # Generate predictions on test set.
    predict_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": test_data},
      num_epochs=1,
      shuffle=False)

    predictions = np.array(list(classifier.predict(input_fn=predict_input_fn))).T
    
    return predictions

# %%
# Load training and validation data
train_dir = 'data/spectrogram/training/'
valid_dir = 'data/spectrogram/validation/'

X_train, Y_train = get_data(os.path.join(train_dir, 'sub_ws500'), 
                            os.path.join(train_dir, 'REFERENCE.csv'))
                            
X_valid, Y_valid = get_data(os.path.join(valid_dir, 'sub_ws500'), 
                            os.path.join(valid_dir, 'REFERENCE.csv'))

# %%
# Run network
pred = main(X_train, Y_train, X_valid, Y_valid, X_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_log_step_count_steps': 100, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_model_dir': 'models/cnn2', '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 96.751, step = 1
# INFO:tensorflow:Saving checkpoints for 25 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 36.9232.
# INFO:tensorflow:Starting evaluation at 2017-11-28-03:29:15
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-25
# INFO:tensorflow:Finished evaluation at 2017-11-28-03:30:21
# INFO:tensorflow:Saving dict for global step 25: accuracy = 0.623675, global_step = 25, loss = 35.5027
# {'loss': 35.502678, 'global_step': 25, 'accuracy': 0.62367493}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-25
# INFO:tensorflow:Saving checkpoints for 26 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 35.1971, step = 26
# INFO:tensorflow:Saving checkpoints for 50 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 10.7346.
# INFO:tensorflow:Starting evaluation at 2017-11-28-03:38:42
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-50
# INFO:tensorflow:Finished evaluation at 2017-11-28-03:39:18
# INFO:tensorflow:Saving dict for global step 50: accuracy = 0.522968, global_step = 50, loss = 10.8998
# {'loss': 10.899769, 'global_step': 50, 'accuracy': 0.52296817}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-50
# INFO:tensorflow:Saving checkpoints for 51 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 10.3352, step = 51
# INFO:tensorflow:Saving checkpoints for 75 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.95689.
# INFO:tensorflow:Starting evaluation at 2017-11-28-03:44:02
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-75
# INFO:tensorflow:Finished evaluation at 2017-11-28-03:44:36
# INFO:tensorflow:Saving dict for global step 75: accuracy = 0.683746, global_step = 75, loss = 3.15027
# {'loss': 3.15027, 'global_step': 75, 'accuracy': 0.68374556}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-75
# INFO:tensorflow:Saving checkpoints for 76 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 2.84051, step = 76
# INFO:tensorflow:Saving checkpoints for 100 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.04448.
# INFO:tensorflow:Starting evaluation at 2017-11-28-03:49:26
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-100
# INFO:tensorflow:Finished evaluation at 2017-11-28-03:50:02
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.649293, global_step = 100, loss = 1.3348
# {'loss': 1.3347958, 'global_step': 100, 'accuracy': 0.6492933}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-100
# INFO:tensorflow:Saving checkpoints for 101 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 1.05127, step = 101
# INFO:tensorflow:Saving checkpoints for 125 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.588655.
# INFO:tensorflow:Starting evaluation at 2017-11-28-03:55:06
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-125
# INFO:tensorflow:Finished evaluation at 2017-11-28-03:55:43
# INFO:tensorflow:Saving dict for global step 125: accuracy = 0.709364, global_step = 125, loss = 0.815243
# {'loss': 0.81524277, 'global_step': 125, 'accuracy': 0.70936394}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-125
# INFO:tensorflow:Saving checkpoints for 126 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.557518, step = 126
# INFO:tensorflow:Saving checkpoints for 150 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.398562.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:00:44
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-150
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:01:21
# INFO:tensorflow:Saving dict for global step 150: accuracy = 0.69523, global_step = 150, loss = 0.859171
# {'loss': 0.85917085, 'global_step': 150, 'accuracy': 0.69522971}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-150
# INFO:tensorflow:Saving checkpoints for 151 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.47508, step = 151
# INFO:tensorflow:Saving checkpoints for 175 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.366571.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:06:37
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-175
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:07:18
# INFO:tensorflow:Saving dict for global step 175: accuracy = 0.646643, global_step = 175, loss = 0.79326
# {'loss': 0.79325974, 'global_step': 175, 'accuracy': 0.6466431}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-175
# INFO:tensorflow:Saving checkpoints for 176 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.351571, step = 176
# INFO:tensorflow:Saving checkpoints for 200 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.288605.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:12:55
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-200
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:13:34
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.583039, global_step = 200, loss = 1.1735
# {'loss': 1.1735036, 'global_step': 200, 'accuracy': 0.58303887}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-200
# INFO:tensorflow:Saving checkpoints for 201 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.565478, step = 201
# INFO:tensorflow:Saving checkpoints for 225 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.368783.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:18:28
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-225
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:19:04
# INFO:tensorflow:Saving dict for global step 225: accuracy = 0.680212, global_step = 225, loss = 0.747534
# {'loss': 0.74753356, 'global_step': 225, 'accuracy': 0.68021202}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-225
# INFO:tensorflow:Saving checkpoints for 226 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.325114, step = 226
# INFO:tensorflow:Saving checkpoints for 250 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.38664.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:24:07
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-250
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:24:46
# INFO:tensorflow:Saving dict for global step 250: accuracy = 0.704064, global_step = 250, loss = 0.755326
# {'loss': 0.75532633, 'global_step': 250, 'accuracy': 0.70406359}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-250
# INFO:tensorflow:Saving checkpoints for 251 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.433196, step = 251
# INFO:tensorflow:Saving checkpoints for 275 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.402901.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:29:35
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-275
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:30:11
# INFO:tensorflow:Saving dict for global step 275: accuracy = 0.699647, global_step = 275, loss = 0.774612
# {'loss': 0.77461153, 'global_step': 275, 'accuracy': 0.69964665}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-275
# INFO:tensorflow:Saving checkpoints for 276 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.411904, step = 276
# INFO:tensorflow:Saving checkpoints for 300 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.347819.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:34:53
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-300
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:35:28
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.650177, global_step = 300, loss = 0.838748
# {'loss': 0.83874822, 'global_step': 300, 'accuracy': 0.6501767}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-300
# INFO:tensorflow:Saving checkpoints for 301 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.387526, step = 301
# INFO:tensorflow:Saving checkpoints for 325 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.348947.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:40:24
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-325
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:41:00
# INFO:tensorflow:Saving dict for global step 325: accuracy = 0.746466, global_step = 325, loss = 0.703325
# {'loss': 0.70332456, 'global_step': 325, 'accuracy': 0.74646646}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-325
# INFO:tensorflow:Saving checkpoints for 326 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.411833, step = 326
# INFO:tensorflow:Saving checkpoints for 350 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.545733.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:45:50
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-350
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:46:27
# INFO:tensorflow:Saving dict for global step 350: accuracy = 0.65106, global_step = 350, loss = 0.920597
# {'loss': 0.92059708, 'global_step': 350, 'accuracy': 0.65106004}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-350
# INFO:tensorflow:Saving checkpoints for 351 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.461618, step = 351
# INFO:tensorflow:Saving checkpoints for 375 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.302071.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:51:15
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-375
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:51:51
# INFO:tensorflow:Saving dict for global step 375: accuracy = 0.75265, global_step = 375, loss = 0.64013
# {'loss': 0.64013004, 'global_step': 375, 'accuracy': 0.7526502}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-375
# INFO:tensorflow:Saving checkpoints for 376 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.238015, step = 376
# INFO:tensorflow:Saving checkpoints for 400 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.267084.
# INFO:tensorflow:Starting evaluation at 2017-11-28-04:56:38
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-400
# INFO:tensorflow:Finished evaluation at 2017-11-28-04:57:16
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.779152, global_step = 400, loss = 0.598073
# {'loss': 0.59807318, 'global_step': 400, 'accuracy': 0.77915192}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-400
# INFO:tensorflow:Saving checkpoints for 401 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.249141, step = 401
# INFO:tensorflow:Saving checkpoints for 425 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3077.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:02:40
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-425
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:03:17
# INFO:tensorflow:Saving dict for global step 425: accuracy = 0.657244, global_step = 425, loss = 0.895343
# {'loss': 0.89534253, 'global_step': 425, 'accuracy': 0.65724379}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-425
# INFO:tensorflow:Saving checkpoints for 426 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.361869, step = 426
# INFO:tensorflow:Saving checkpoints for 450 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.314405.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:08:19
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-450
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:08:57
# INFO:tensorflow:Saving dict for global step 450: accuracy = 0.647527, global_step = 450, loss = 0.995485
# {'loss': 0.99548489, 'global_step': 450, 'accuracy': 0.6475265}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-450
# INFO:tensorflow:Saving checkpoints for 451 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.257172, step = 451
# INFO:tensorflow:Saving checkpoints for 475 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.325855.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:14:00
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-475
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:14:39
# INFO:tensorflow:Saving dict for global step 475: accuracy = 0.765901, global_step = 475, loss = 0.582265
# {'loss': 0.58226466, 'global_step': 475, 'accuracy': 0.76590109}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-475
# INFO:tensorflow:Saving checkpoints for 476 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.33983, step = 476
# INFO:tensorflow:Saving checkpoints for 500 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.298887.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:19:39
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-500
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:20:18
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.754417, global_step = 500, loss = 0.649546
# {'loss': 0.64954579, 'global_step': 500, 'accuracy': 0.75441694}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-500
# INFO:tensorflow:Saving checkpoints for 501 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.258093, step = 501
# INFO:tensorflow:Saving checkpoints for 525 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.328868.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:25:20
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-525
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:25:59
# INFO:tensorflow:Saving dict for global step 525: accuracy = 0.711131, global_step = 525, loss = 0.622633
# {'loss': 0.6226331, 'global_step': 525, 'accuracy': 0.71113074}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-525
# INFO:tensorflow:Saving checkpoints for 526 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.226542, step = 526
# INFO:tensorflow:Saving checkpoints for 550 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.252611.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:31:01
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-550
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:31:40
# INFO:tensorflow:Saving dict for global step 550: accuracy = 0.80212, global_step = 550, loss = 0.642272
# {'loss': 0.64227241, 'global_step': 550, 'accuracy': 0.80212015}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-550
# INFO:tensorflow:Saving checkpoints for 551 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.34187, step = 551
# INFO:tensorflow:Saving checkpoints for 575 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.328546.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:36:46
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-575
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:37:23
# INFO:tensorflow:Saving dict for global step 575: accuracy = 0.742049, global_step = 575, loss = 0.686715
# {'loss': 0.68671483, 'global_step': 575, 'accuracy': 0.74204946}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-575
# INFO:tensorflow:Saving checkpoints for 576 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.248833, step = 576
# INFO:tensorflow:Saving checkpoints for 600 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.390938.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:42:26
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-600
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:43:06
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.813604, global_step = 600, loss = 0.579548
# {'loss': 0.57954794, 'global_step': 600, 'accuracy': 0.81360424}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-600
# INFO:tensorflow:Saving checkpoints for 601 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.281039, step = 601
# INFO:tensorflow:Saving checkpoints for 625 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.269762.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:48:13
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-625
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:48:49
# INFO:tensorflow:Saving dict for global step 625: accuracy = 0.750883, global_step = 625, loss = 0.630284
# {'loss': 0.63028353, 'global_step': 625, 'accuracy': 0.7508834}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-625
# INFO:tensorflow:Saving checkpoints for 626 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.304448, step = 626
# INFO:tensorflow:Saving checkpoints for 650 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.302058.
# INFO:tensorflow:Starting evaluation at 2017-11-28-05:54:28
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-650
# INFO:tensorflow:Finished evaluation at 2017-11-28-05:55:07
# INFO:tensorflow:Saving dict for global step 650: accuracy = 0.758834, global_step = 650, loss = 0.615699
# {'loss': 0.61569905, 'global_step': 650, 'accuracy': 0.75883394}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-650
# INFO:tensorflow:Saving checkpoints for 651 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.349997, step = 651
# INFO:tensorflow:Saving checkpoints for 675 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.188901.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:02:49
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-675
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:03:56
# INFO:tensorflow:Saving dict for global step 675: accuracy = 0.778269, global_step = 675, loss = 0.68199
# {'loss': 0.68198961, 'global_step': 675, 'accuracy': 0.77826858}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-675
# INFO:tensorflow:Saving checkpoints for 676 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.231388, step = 676
# INFO:tensorflow:Saving checkpoints for 700 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.226806.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:14:06
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-700
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:17:17
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.803004, global_step = 700, loss = 0.670129
# {'loss': 0.67012882, 'global_step': 700, 'accuracy': 0.80300355}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-700
# INFO:tensorflow:Saving checkpoints for 701 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.257053, step = 701
# INFO:tensorflow:Saving checkpoints for 724 into models/cnn2/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 725 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.272603.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:28:56
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-725
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:30:14
# INFO:tensorflow:Saving dict for global step 725: accuracy = 0.728799, global_step = 725, loss = 0.626437
# {'loss': 0.62643653, 'global_step': 725, 'accuracy': 0.72879857}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-725
# INFO:tensorflow:Saving checkpoints for 726 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.28066, step = 726
# INFO:tensorflow:Saving checkpoints for 750 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.344808.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:40:49
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-750
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:42:02
# INFO:tensorflow:Saving dict for global step 750: accuracy = 0.719965, global_step = 750, loss = 0.663854
# {'loss': 0.66385388, 'global_step': 750, 'accuracy': 0.71996468}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-750
# INFO:tensorflow:Saving checkpoints for 751 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.329755, step = 751
# INFO:tensorflow:Saving checkpoints for 775 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.315623.
# INFO:tensorflow:Starting evaluation at 2017-11-28-06:51:05
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-775
# INFO:tensorflow:Finished evaluation at 2017-11-28-06:52:14
# INFO:tensorflow:Saving dict for global step 775: accuracy = 0.765018, global_step = 775, loss = 0.584536
# {'loss': 0.58453631, 'global_step': 775, 'accuracy': 0.76501769}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-775
# INFO:tensorflow:Saving checkpoints for 776 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.330879, step = 776
# INFO:tensorflow:Saving checkpoints for 800 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.248778.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:00:59
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-800
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:02:09
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.757951, global_step = 800, loss = 0.631461
# {'loss': 0.63146138, 'global_step': 800, 'accuracy': 0.75795054}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-800
# INFO:tensorflow:Saving checkpoints for 801 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.332084, step = 801
# INFO:tensorflow:Saving checkpoints for 825 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.271052.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:11:04
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-825
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:12:10
# INFO:tensorflow:Saving dict for global step 825: accuracy = 0.7447, global_step = 825, loss = 0.657615
# {'loss': 0.65761542, 'global_step': 825, 'accuracy': 0.74469966}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-825
# INFO:tensorflow:Saving checkpoints for 826 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.273564, step = 826
# INFO:tensorflow:Saving checkpoints for 850 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.228831.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:21:00
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-850
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:22:09
# INFO:tensorflow:Saving dict for global step 850: accuracy = 0.75265, global_step = 850, loss = 0.712233
# {'loss': 0.71223283, 'global_step': 850, 'accuracy': 0.7526502}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-850
# INFO:tensorflow:Saving checkpoints for 851 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.278603, step = 851
# INFO:tensorflow:Saving checkpoints for 875 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.261045.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:30:48
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-875
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:31:58
# INFO:tensorflow:Saving dict for global step 875: accuracy = 0.795936, global_step = 875, loss = 0.59268
# {'loss': 0.59268004, 'global_step': 875, 'accuracy': 0.79593641}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-875
# INFO:tensorflow:Saving checkpoints for 876 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.212294, step = 876
# INFO:tensorflow:Saving checkpoints for 900 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.245549.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:40:48
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-900
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:41:52
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.741166, global_step = 900, loss = 0.690238
# {'loss': 0.69023818, 'global_step': 900, 'accuracy': 0.74116606}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-900
# INFO:tensorflow:Saving checkpoints for 901 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.26265, step = 901
# INFO:tensorflow:Saving checkpoints for 925 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.353618.
# INFO:tensorflow:Starting evaluation at 2017-11-28-07:50:35
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-925
# INFO:tensorflow:Finished evaluation at 2017-11-28-07:51:44
# INFO:tensorflow:Saving dict for global step 925: accuracy = 0.683746, global_step = 925, loss = 0.789689
# {'loss': 0.78968883, 'global_step': 925, 'accuracy': 0.68374556}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-925
# INFO:tensorflow:Saving checkpoints for 926 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.291906, step = 926
# INFO:tensorflow:Saving checkpoints for 950 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.209707.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:00:21
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-950
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:01:30
# INFO:tensorflow:Saving dict for global step 950: accuracy = 0.782686, global_step = 950, loss = 0.593693
# {'loss': 0.59369284, 'global_step': 950, 'accuracy': 0.78268552}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-950
# INFO:tensorflow:Saving checkpoints for 951 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.292642, step = 951
# INFO:tensorflow:Saving checkpoints for 975 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.214169.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:10:20
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-975
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:11:25
# INFO:tensorflow:Saving dict for global step 975: accuracy = 0.757951, global_step = 975, loss = 0.716547
# {'loss': 0.71654743, 'global_step': 975, 'accuracy': 0.75795054}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-975
# INFO:tensorflow:Saving checkpoints for 976 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.229764, step = 976
# INFO:tensorflow:Saving checkpoints for 1000 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.319739.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:20:10
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:21:19
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.761484, global_step = 1000, loss = 0.5898
# {'loss': 0.58980012, 'global_step': 1000, 'accuracy': 0.76148409}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1000
# INFO:tensorflow:Saving checkpoints for 1001 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.26895, step = 1001
# INFO:tensorflow:Saving checkpoints for 1025 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.267923.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:29:59
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1025
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:31:08
# INFO:tensorflow:Saving dict for global step 1025: accuracy = 0.74735, global_step = 1025, loss = 0.645989
# {'loss': 0.64598918, 'global_step': 1025, 'accuracy': 0.7473498}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1025
# INFO:tensorflow:Saving checkpoints for 1026 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.317456, step = 1026
# INFO:tensorflow:Saving checkpoints for 1050 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.384286.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:39:58
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1050
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:41:03
# INFO:tensorflow:Saving dict for global step 1050: accuracy = 0.798587, global_step = 1050, loss = 0.756512
# {'loss': 0.75651199, 'global_step': 1050, 'accuracy': 0.79858655}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1050
# INFO:tensorflow:Saving checkpoints for 1051 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.383697, step = 1051
# INFO:tensorflow:Saving checkpoints for 1075 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.227326.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:49:48
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1075
# INFO:tensorflow:Finished evaluation at 2017-11-28-08:50:56
# INFO:tensorflow:Saving dict for global step 1075: accuracy = 0.768551, global_step = 1075, loss = 0.559777
# {'loss': 0.55977654, 'global_step': 1075, 'accuracy': 0.76855123}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1075
# INFO:tensorflow:Saving checkpoints for 1076 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.238543, step = 1076
# INFO:tensorflow:Saving checkpoints for 1100 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.20574.
# INFO:tensorflow:Starting evaluation at 2017-11-28-08:59:34
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1100
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:00:43
# INFO:tensorflow:Saving dict for global step 1100: accuracy = 0.753534, global_step = 1100, loss = 0.641851
# {'loss': 0.64185095, 'global_step': 1100, 'accuracy': 0.75353354}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1100
# INFO:tensorflow:Saving checkpoints for 1101 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.289203, step = 1101
# INFO:tensorflow:Saving checkpoints for 1125 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16549.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:09:31
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1125
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:10:36
# INFO:tensorflow:Saving dict for global step 1125: accuracy = 0.737633, global_step = 1125, loss = 0.648119
# {'loss': 0.64811885, 'global_step': 1125, 'accuracy': 0.73763251}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1125
# INFO:tensorflow:Saving checkpoints for 1126 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.225111, step = 1126
# INFO:tensorflow:Saving checkpoints for 1150 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.207264.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:19:20
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1150
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:20:29
# INFO:tensorflow:Saving dict for global step 1150: accuracy = 0.779152, global_step = 1150, loss = 0.562894
# {'loss': 0.56289446, 'global_step': 1150, 'accuracy': 0.77915192}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1150
# INFO:tensorflow:Saving checkpoints for 1151 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.217915, step = 1151
# INFO:tensorflow:Saving checkpoints for 1175 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.186986.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:29:26
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1175
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:30:34
# INFO:tensorflow:Saving dict for global step 1175: accuracy = 0.771201, global_step = 1175, loss = 0.705448
# {'loss': 0.70544755, 'global_step': 1175, 'accuracy': 0.77120143}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1175
# INFO:tensorflow:Saving checkpoints for 1176 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.197435, step = 1176
# INFO:tensorflow:Saving checkpoints for 1200 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.196348.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:39:23
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1200
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:40:26
# INFO:tensorflow:Saving dict for global step 1200: accuracy = 0.784452, global_step = 1200, loss = 0.598796
# {'loss': 0.59879577, 'global_step': 1200, 'accuracy': 0.78445232}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1200
# INFO:tensorflow:Saving checkpoints for 1201 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.202981, step = 1201
# INFO:tensorflow:Saving checkpoints for 1225 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.215186.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:49:08
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1225
# INFO:tensorflow:Finished evaluation at 2017-11-28-09:50:17
# INFO:tensorflow:Saving dict for global step 1225: accuracy = 0.774735, global_step = 1225, loss = 0.630945
# {'loss': 0.63094461, 'global_step': 1225, 'accuracy': 0.77473497}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1225
# INFO:tensorflow:Saving checkpoints for 1226 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.204744, step = 1226
# INFO:tensorflow:Saving checkpoints for 1250 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.183555.
# INFO:tensorflow:Starting evaluation at 2017-11-28-09:58:53
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1250
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:00:01
# INFO:tensorflow:Saving dict for global step 1250: accuracy = 0.772085, global_step = 1250, loss = 0.723465
# {'loss': 0.72346526, 'global_step': 1250, 'accuracy': 0.77208483}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1250
# INFO:tensorflow:Saving checkpoints for 1251 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.270734, step = 1251
# INFO:tensorflow:Saving checkpoints for 1275 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.214179.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:08:46
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1275
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:09:51
# INFO:tensorflow:Saving dict for global step 1275: accuracy = 0.64841, global_step = 1275, loss = 0.980021
# {'loss': 0.98002094, 'global_step': 1275, 'accuracy': 0.6484099}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1275
# INFO:tensorflow:Saving checkpoints for 1276 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.242299, step = 1276
# INFO:tensorflow:Saving checkpoints for 1300 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.27583.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:18:32
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1300
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:19:40
# INFO:tensorflow:Saving dict for global step 1300: accuracy = 0.822438, global_step = 1300, loss = 0.618618
# {'loss': 0.61861825, 'global_step': 1300, 'accuracy': 0.82243818}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1300
# INFO:tensorflow:Saving checkpoints for 1301 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.238861, step = 1301
# INFO:tensorflow:Saving checkpoints for 1325 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.199333.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:28:18
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1325
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:29:26
# INFO:tensorflow:Saving dict for global step 1325: accuracy = 0.766784, global_step = 1325, loss = 0.605628
# {'loss': 0.60562795, 'global_step': 1325, 'accuracy': 0.76678443}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1325
# INFO:tensorflow:Saving checkpoints for 1326 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.130324, step = 1326
# INFO:tensorflow:Saving checkpoints for 1350 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.231775.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:38:16
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1350
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:39:21
# INFO:tensorflow:Saving dict for global step 1350: accuracy = 0.708481, global_step = 1350, loss = 0.766886
# {'loss': 0.76688617, 'global_step': 1350, 'accuracy': 0.70848054}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1350
# INFO:tensorflow:Saving checkpoints for 1351 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.198081, step = 1351
# INFO:tensorflow:Saving checkpoints for 1375 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.155444.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:48:04
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1375
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:49:13
# INFO:tensorflow:Saving dict for global step 1375: accuracy = 0.741166, global_step = 1375, loss = 0.722624
# {'loss': 0.72262448, 'global_step': 1375, 'accuracy': 0.74116606}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1375
# INFO:tensorflow:Saving checkpoints for 1376 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.248037, step = 1376
# INFO:tensorflow:Saving checkpoints for 1400 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.22942.
# INFO:tensorflow:Starting evaluation at 2017-11-28-10:57:49
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1400
# INFO:tensorflow:Finished evaluation at 2017-11-28-10:58:59
# INFO:tensorflow:Saving dict for global step 1400: accuracy = 0.738516, global_step = 1400, loss = 0.8201
# {'loss': 0.82010007, 'global_step': 1400, 'accuracy': 0.73851591}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1400
# INFO:tensorflow:Saving checkpoints for 1401 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.230731, step = 1401
# INFO:tensorflow:Saving checkpoints for 1425 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.299496.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:07:49
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1425
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:08:53
# INFO:tensorflow:Saving dict for global step 1425: accuracy = 0.754417, global_step = 1425, loss = 0.684832
# {'loss': 0.68483233, 'global_step': 1425, 'accuracy': 0.75441694}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1425
# INFO:tensorflow:Saving checkpoints for 1426 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.17912, step = 1426
# INFO:tensorflow:Saving checkpoints for 1450 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.245165.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:17:37
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1450
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:18:46
# INFO:tensorflow:Saving dict for global step 1450: accuracy = 0.750883, global_step = 1450, loss = 0.617461
# {'loss': 0.61746073, 'global_step': 1450, 'accuracy': 0.7508834}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1450
# INFO:tensorflow:Saving checkpoints for 1451 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.185285, step = 1451
# INFO:tensorflow:Saving checkpoints for 1475 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.261893.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:27:25
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1475
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:28:34
# INFO:tensorflow:Saving dict for global step 1475: accuracy = 0.798587, global_step = 1475, loss = 0.615193
# {'loss': 0.61519265, 'global_step': 1475, 'accuracy': 0.79858655}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1475
# INFO:tensorflow:Saving checkpoints for 1476 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.161835, step = 1476
# INFO:tensorflow:Saving checkpoints for 1500 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.299113.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:37:29
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1500
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:38:33
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.709364, global_step = 1500, loss = 0.711014
# {'loss': 0.71101362, 'global_step': 1500, 'accuracy': 0.70936394}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1500
# INFO:tensorflow:Saving checkpoints for 1501 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.301586, step = 1501
# INFO:tensorflow:Saving checkpoints for 1525 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.327673.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:47:19
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1525
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:48:29
# INFO:tensorflow:Saving dict for global step 1525: accuracy = 0.730565, global_step = 1525, loss = 0.741403
# {'loss': 0.74140251, 'global_step': 1525, 'accuracy': 0.73056537}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1525
# INFO:tensorflow:Saving checkpoints for 1526 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.20699, step = 1526
# INFO:tensorflow:Saving checkpoints for 1550 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.229201.
# INFO:tensorflow:Starting evaluation at 2017-11-28-11:57:07
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1550
# INFO:tensorflow:Finished evaluation at 2017-11-28-11:58:16
# INFO:tensorflow:Saving dict for global step 1550: accuracy = 0.757951, global_step = 1550, loss = 0.725814
# {'loss': 0.72581363, 'global_step': 1550, 'accuracy': 0.75795054}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1550
# INFO:tensorflow:Saving checkpoints for 1551 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.275541, step = 1551
# INFO:tensorflow:Saving checkpoints for 1575 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.172401.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:07:08
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1575
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:08:11
# INFO:tensorflow:Saving dict for global step 1575: accuracy = 0.775618, global_step = 1575, loss = 0.714417
# {'loss': 0.71441674, 'global_step': 1575, 'accuracy': 0.77561837}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1575
# INFO:tensorflow:Saving checkpoints for 1576 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.217834, step = 1576
# INFO:tensorflow:Saving checkpoints for 1600 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.257748.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:17:00
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1600
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:18:09
# INFO:tensorflow:Saving dict for global step 1600: accuracy = 0.793286, global_step = 1600, loss = 0.54829
# {'loss': 0.54829001, 'global_step': 1600, 'accuracy': 0.7932862}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1600
# INFO:tensorflow:Saving checkpoints for 1601 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.256317, step = 1601
# INFO:tensorflow:Saving checkpoints for 1625 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.271445.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:26:50
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1625
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:27:59
# INFO:tensorflow:Saving dict for global step 1625: accuracy = 0.808304, global_step = 1625, loss = 0.557635
# {'loss': 0.55763495, 'global_step': 1625, 'accuracy': 0.80830389}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1625
# INFO:tensorflow:Saving checkpoints for 1626 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.208844, step = 1626
# INFO:tensorflow:Saving checkpoints for 1650 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.276383.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:36:49
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1650
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:37:53
# INFO:tensorflow:Saving dict for global step 1650: accuracy = 0.7447, global_step = 1650, loss = 0.764481
# {'loss': 0.76448107, 'global_step': 1650, 'accuracy': 0.74469966}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1650
# INFO:tensorflow:Saving checkpoints for 1651 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.283128, step = 1651
# INFO:tensorflow:Saving checkpoints for 1675 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.245888.
# INFO:tensorflow:Starting evaluation at 2017-11-28-12:46:37
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1675
# INFO:tensorflow:Finished evaluation at 2017-11-28-12:47:46
# INFO:tensorflow:Saving dict for global step 1675: accuracy = 0.65371, global_step = 1675, loss = 1.01832
# {'loss': 1.0183197, 'global_step': 1675, 'accuracy': 0.65371025}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1675
# INFO:tensorflow:Saving checkpoints for 1676 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.296431, step = 1676
# INFO:tensorflow:Saving checkpoints for 1700 into models/cnn2/model.ckpt.
# ...
# INFO:tensorflow:Saving dict for global step 1950: accuracy = 0.753534, global_step = 1950, loss = 0.671599
# {'loss': 0.67159933, 'global_step': 1950, 'accuracy': 0.75353354}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1950
# INFO:tensorflow:Saving checkpoints for 1951 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.225812, step = 1951
# INFO:tensorflow:Saving checkpoints for 1967 into models/cnn2/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1975 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.185931.
# INFO:tensorflow:Starting evaluation at 2017-11-28-15:35:13
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1975
# INFO:tensorflow:Finished evaluation at 2017-11-28-15:36:22
# INFO:tensorflow:Saving dict for global step 1975: accuracy = 0.770318, global_step = 1975, loss = 0.854231
# {'loss': 0.85423088, 'global_step': 1975, 'accuracy': 0.77031803}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-1975
# INFO:tensorflow:Saving checkpoints for 1976 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.202798, step = 1976
# INFO:tensorflow:Saving checkpoints for 2000 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.257375.
# INFO:tensorflow:Starting evaluation at 2017-11-28-15:45:48
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2000
# INFO:tensorflow:Finished evaluation at 2017-11-28-15:47:00
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.792403, global_step = 2000, loss = 0.607641
# {'loss': 0.60764086, 'global_step': 2000, 'accuracy': 0.7924028}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2000
# INFO:tensorflow:Saving checkpoints for 2001 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.231432, step = 2001
# INFO:tensorflow:Saving checkpoints for 2025 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.167654.
# INFO:tensorflow:Starting evaluation at 2017-11-28-15:56:25
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2025
# INFO:tensorflow:Finished evaluation at 2017-11-28-15:57:30
# INFO:tensorflow:Saving dict for global step 2025: accuracy = 0.774735, global_step = 2025, loss = 0.698924
# {'loss': 0.69892424, 'global_step': 2025, 'accuracy': 0.77473497}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2025
# INFO:tensorflow:Saving checkpoints for 2026 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.27859, step = 2026
# INFO:tensorflow:Saving checkpoints for 2050 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.255598.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:07:55
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2050
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:09:07
# INFO:tensorflow:Saving dict for global step 2050: accuracy = 0.727032, global_step = 2050, loss = 0.929538
# {'loss': 0.92953807, 'global_step': 2050, 'accuracy': 0.72703183}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2050
# INFO:tensorflow:Saving checkpoints for 2051 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.158434, step = 2051
# INFO:tensorflow:Saving checkpoints for 2075 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.182385.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:18:11
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2075
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:19:23
# INFO:tensorflow:Saving dict for global step 2075: accuracy = 0.784452, global_step = 2075, loss = 0.688158
# {'loss': 0.6881578, 'global_step': 2075, 'accuracy': 0.78445232}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2075
# INFO:tensorflow:Saving checkpoints for 2076 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.196313, step = 2076
# INFO:tensorflow:Saving checkpoints for 2100 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.185371.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:28:21
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2100
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:29:24
# INFO:tensorflow:Saving dict for global step 2100: accuracy = 0.776502, global_step = 2100, loss = 0.793827
# {'loss': 0.79382694, 'global_step': 2100, 'accuracy': 0.77650177}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2100
# INFO:tensorflow:Saving checkpoints for 2101 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.153103, step = 2101
# INFO:tensorflow:Saving checkpoints for 2125 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.18636.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:38:25
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2125
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:39:36
# INFO:tensorflow:Saving dict for global step 2125: accuracy = 0.774735, global_step = 2125, loss = 0.700726
# {'loss': 0.70072627, 'global_step': 2125, 'accuracy': 0.77473497}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2125
# INFO:tensorflow:Saving checkpoints for 2126 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.193163, step = 2126
# INFO:tensorflow:Saving checkpoints for 2150 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.243043.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:48:35
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2150
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:49:45
# INFO:tensorflow:Saving dict for global step 2150: accuracy = 0.690813, global_step = 2150, loss = 1.15013
# {'loss': 1.1501253, 'global_step': 2150, 'accuracy': 0.69081271}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2150
# INFO:tensorflow:Saving checkpoints for 2151 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.424131, step = 2151
# INFO:tensorflow:Saving checkpoints for 2175 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.324607.
# INFO:tensorflow:Starting evaluation at 2017-11-28-16:56:42
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2175
# INFO:tensorflow:Finished evaluation at 2017-11-28-16:57:20
# INFO:tensorflow:Saving dict for global step 2175: accuracy = 0.732332, global_step = 2175, loss = 0.866177
# {'loss': 0.86617696, 'global_step': 2175, 'accuracy': 0.73233217}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2175
# INFO:tensorflow:Saving checkpoints for 2176 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.242917, step = 2176
# INFO:tensorflow:Saving checkpoints for 2200 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.211453.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:02:15
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2200
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:02:54
# INFO:tensorflow:Saving dict for global step 2200: accuracy = 0.798587, global_step = 2200, loss = 0.647097
# {'loss': 0.64709735, 'global_step': 2200, 'accuracy': 0.79858655}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2200
# INFO:tensorflow:Saving checkpoints for 2201 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.247659, step = 2201
# INFO:tensorflow:Saving checkpoints for 2225 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.298227.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:08:20
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2225
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:09:01
# INFO:tensorflow:Saving dict for global step 2225: accuracy = 0.79947, global_step = 2225, loss = 0.581691
# {'loss': 0.58169132, 'global_step': 2225, 'accuracy': 0.79946995}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2225
# INFO:tensorflow:Saving checkpoints for 2226 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.203008, step = 2226
# INFO:tensorflow:Saving checkpoints for 2250 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.212623.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:13:53
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2250
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:14:32
# INFO:tensorflow:Saving dict for global step 2250: accuracy = 0.742933, global_step = 2250, loss = 0.762614
# {'loss': 0.76261353, 'global_step': 2250, 'accuracy': 0.74293286}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2250
# INFO:tensorflow:Saving checkpoints for 2251 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.193566, step = 2251
# INFO:tensorflow:Saving checkpoints for 2275 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.173073.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:19:33
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2275
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:20:11
# INFO:tensorflow:Saving dict for global step 2275: accuracy = 0.788869, global_step = 2275, loss = 0.607297
# {'loss': 0.60729712, 'global_step': 2275, 'accuracy': 0.78886926}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2275
# INFO:tensorflow:Saving checkpoints for 2276 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.197856, step = 2276
# INFO:tensorflow:Saving checkpoints for 2300 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.232298.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:25:00
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2300
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:25:40
# INFO:tensorflow:Saving dict for global step 2300: accuracy = 0.792403, global_step = 2300, loss = 0.713292
# {'loss': 0.71329236, 'global_step': 2300, 'accuracy': 0.7924028}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2300
# INFO:tensorflow:Saving checkpoints for 2301 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.19632, step = 2301
# INFO:tensorflow:Saving checkpoints for 2325 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.175881.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:31:04
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2325
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:31:45
# INFO:tensorflow:Saving dict for global step 2325: accuracy = 0.798587, global_step = 2325, loss = 0.666858
# {'loss': 0.6668579, 'global_step': 2325, 'accuracy': 0.79858655}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2325
# INFO:tensorflow:Saving checkpoints for 2326 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.142873, step = 2326
# INFO:tensorflow:Saving checkpoints for 2350 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.197813.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:37:04
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2350
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:37:43
# INFO:tensorflow:Saving dict for global step 2350: accuracy = 0.79682, global_step = 2350, loss = 0.713175
# {'loss': 0.71317476, 'global_step': 2350, 'accuracy': 0.79681981}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2350
# INFO:tensorflow:Saving checkpoints for 2351 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.200309, step = 2351
# INFO:tensorflow:Saving checkpoints for 2375 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.373778.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:42:44
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2375
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:43:21
# INFO:tensorflow:Saving dict for global step 2375: accuracy = 0.801237, global_step = 2375, loss = 0.802042
# {'loss': 0.80204177, 'global_step': 2375, 'accuracy': 0.80123675}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2375
# INFO:tensorflow:Saving checkpoints for 2376 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.264349, step = 2376
# INFO:tensorflow:Saving checkpoints for 2400 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.403931.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:48:06
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2400
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:48:43
# INFO:tensorflow:Saving dict for global step 2400: accuracy = 0.767668, global_step = 2400, loss = 0.929136
# {'loss': 0.9291364, 'global_step': 2400, 'accuracy': 0.76766783}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2400
# INFO:tensorflow:Saving checkpoints for 2401 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.28709, step = 2401
# INFO:tensorflow:Saving checkpoints for 2425 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.160039.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:53:34
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2425
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:54:12
# INFO:tensorflow:Saving dict for global step 2425: accuracy = 0.80212, global_step = 2425, loss = 0.683257
# {'loss': 0.68325698, 'global_step': 2425, 'accuracy': 0.80212015}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2425
# INFO:tensorflow:Saving checkpoints for 2426 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.171119, step = 2426
# INFO:tensorflow:Saving checkpoints for 2450 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.130156.
# INFO:tensorflow:Starting evaluation at 2017-11-28-17:59:07
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2450
# INFO:tensorflow:Finished evaluation at 2017-11-28-17:59:44
# INFO:tensorflow:Saving dict for global step 2450: accuracy = 0.810954, global_step = 2450, loss = 0.733094
# {'loss': 0.73309368, 'global_step': 2450, 'accuracy': 0.81095403}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2450
# INFO:tensorflow:Saving checkpoints for 2451 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.130607, step = 2451
# INFO:tensorflow:Saving checkpoints for 2475 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.133449.
# INFO:tensorflow:Starting evaluation at 2017-11-28-18:04:53
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2475
# INFO:tensorflow:Finished evaluation at 2017-11-28-18:05:32
# INFO:tensorflow:Saving dict for global step 2475: accuracy = 0.808304, global_step = 2475, loss = 0.799733
# {'loss': 0.79973274, 'global_step': 2475, 'accuracy': 0.80830389}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2475
# INFO:tensorflow:Saving checkpoints for 2476 into models/cnn2/model.ckpt.
# INFO:tensorflow:loss = 0.115026, step = 2476
# INFO:tensorflow:Saving checkpoints for 2500 into models/cnn2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.398679.
# INFO:tensorflow:Starting evaluation at 2017-11-28-18:10:52
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2500
# INFO:tensorflow:Finished evaluation at 2017-11-28-18:11:30
# INFO:tensorflow:Saving dict for global step 2500: accuracy = 0.774735, global_step = 2500, loss = 0.869549
# {'loss': 0.86954868, 'global_step': 2500, 'accuracy': 0.77473497}
# INFO:tensorflow:Restoring parameters from models/cnn2/model.ckpt-2500

# %%
# Run network
pred = main(X_train, Y_train, X_valid, Y_valid, X_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_model_dir': 'models-test-estimator/', '_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_session_config': None, '_log_step_count_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 60.3213, step = 1
# INFO:tensorflow:Saving checkpoints for 72 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 100 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.895572.
# INFO:tensorflow:Starting evaluation at 2017-11-19-22:33:41
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-100
# INFO:tensorflow:Finished evaluation at 2017-11-19-22:34:02
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.720848, global_step = 100, loss = 1.18861
# {'loss': 1.1886137, 'global_step': 100, 'accuracy': 0.72084808}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-100
# INFO:tensorflow:Saving checkpoints for 101 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.900437, step = 101
# INFO:tensorflow:Saving checkpoints for 131 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 200 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.273767.
# INFO:tensorflow:Starting evaluation at 2017-11-20-00:18:03
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-200
# INFO:tensorflow:Finished evaluation at 2017-11-20-00:18:26
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.797703, global_step = 200, loss = 0.516123
# {'loss': 0.51612258, 'global_step': 200, 'accuracy': 0.79770321}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-200
# INFO:tensorflow:Saving checkpoints for 201 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.27112, step = 201
# INFO:tensorflow:Saving checkpoints for 261 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 300 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.273135.
# INFO:tensorflow:Starting evaluation at 2017-11-20-00:35:26
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-300
# INFO:tensorflow:Finished evaluation at 2017-11-20-00:35:55
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.789753, global_step = 300, loss = 0.55483
# {'loss': 0.55483007, 'global_step': 300, 'accuracy': 0.78975266}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-300
# INFO:tensorflow:Saving checkpoints for 301 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.186627, step = 301
# INFO:tensorflow:Saving checkpoints for 363 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 400 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.261198.
# INFO:tensorflow:Starting evaluation at 2017-11-20-00:51:48
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-400
# INFO:tensorflow:Finished evaluation at 2017-11-20-00:52:11
# INFO:tensorflow:Saving dict for global step 400: accuracy = 0.742933, global_step = 400, loss = 0.545087
# {'loss': 0.54508698, 'global_step': 400, 'accuracy': 0.74293286}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-400
# INFO:tensorflow:Saving checkpoints for 401 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.299955, step = 401
# INFO:tensorflow:Saving checkpoints for 468 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 500 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.257225.
# INFO:tensorflow:Starting evaluation at 2017-11-20-01:07:35
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-500
# INFO:tensorflow:Finished evaluation at 2017-11-20-01:08:00
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.806537, global_step = 500, loss = 0.515962
# {'loss': 0.51596189, 'global_step': 500, 'accuracy': 0.80653709}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-500
# INFO:tensorflow:Saving checkpoints for 501 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.228074, step = 501
# INFO:tensorflow:Saving checkpoints for 561 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 600 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.211994.
# INFO:tensorflow:Starting evaluation at 2017-11-20-01:23:49
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-600
# INFO:tensorflow:Finished evaluation at 2017-11-20-01:24:10
# INFO:tensorflow:Saving dict for global step 600: accuracy = 0.805654, global_step = 600, loss = 0.519708
# {'loss': 0.5197084, 'global_step': 600, 'accuracy': 0.80565369}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-600
# INFO:tensorflow:Saving checkpoints for 601 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.199173, step = 601
# INFO:tensorflow:Saving checkpoints for 670 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 700 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.180829.
# INFO:tensorflow:Starting evaluation at 2017-11-20-01:39:29
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-700
# INFO:tensorflow:Finished evaluation at 2017-11-20-01:39:57
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.742933, global_step = 700, loss = 0.641556
# {'loss': 0.64155644, 'global_step': 700, 'accuracy': 0.74293286}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-700
# INFO:tensorflow:Saving checkpoints for 701 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.206732, step = 701
# INFO:tensorflow:Saving checkpoints for 757 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 800 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.293789.
# INFO:tensorflow:Starting evaluation at 2017-11-20-01:59:18
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-800
# INFO:tensorflow:Finished evaluation at 2017-11-20-01:59:45
# INFO:tensorflow:Saving dict for global step 800: accuracy = 0.766784, global_step = 800, loss = 0.604053
# {'loss': 0.60405266, 'global_step': 800, 'accuracy': 0.76678443}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-800
# INFO:tensorflow:Saving checkpoints for 801 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.199741, step = 801
# INFO:tensorflow:Saving checkpoints for 858 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 900 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.189586.
# INFO:tensorflow:Starting evaluation at 2017-11-20-02:18:20
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-900
# INFO:tensorflow:Finished evaluation at 2017-11-20-02:18:51
# INFO:tensorflow:Saving dict for global step 900: accuracy = 0.795936, global_step = 900, loss = 0.613583
# {'loss': 0.61358339, 'global_step': 900, 'accuracy': 0.79593641}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-900
# INFO:tensorflow:Saving checkpoints for 901 into models-test-estimator/model.ckpt.
# INFO:tensorflow:loss = 0.207821, step = 901
# INFO:tensorflow:Saving checkpoints for 958 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1000 into models-test-estimator/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.275022.
# INFO:tensorflow:Starting evaluation at 2017-11-20-02:36:28
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-20-02:36:52
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.783569, global_step = 1000, loss = 0.608566
# {'loss': 0.60856622, 'global_step': 1000, 'accuracy': 0.78356892}
# INFO:tensorflow:Restoring parameters from models-test-estimator/model.ckpt-1000
